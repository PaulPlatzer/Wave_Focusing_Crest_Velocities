# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn import linear_model
from scipy.optimize import curve_fit

# %% [markdown]
# # Solving the Non-Linear Schrödinger Equation
#
# In the reference frame moving with the group velocity of waves, the Non-Linear Schrödinger equation for the envelope $u$ of 1D deep-water ocean surgace gravity waves is
# $$i \partial_t u =\frac{\omega_0}{8k_0^2}\partial_{xx} u+\frac{1}{2}\omega_0 k_0^2 |u|^2 u \, , $$
#
# where $\omega_0$ and $k_0$ are the peak pulse and wavenumber of the wave field which is represented as the real part of $u(x,t)\exp i\left(\omega_0 t -k_0 x \right)$, where $x$ is position and $t$ time.
#
# This equation can be non-dimensionalized setting $T=\omega_0 t$, $X=2\sqrt{2}k_0 x$, $U= \frac{k_0}{\sqrt{2}} u$, giving
#
# $$ i\partial_T U = \partial_{XX} U + |U|^2U \, . $$
#
# It will be solved using a pseudo-spectral scheme (see https://en.wikipedia.org/wiki/Pseudo-spectral_method) as is done in Adcock & Taylor (2009, see section 2 for details on the equation and section 3 for details concerning the numerical integration). The shape of the Gaussian wavenumber spectrum is fitted to a JONSWAP spectrum with $\gamma=3.3$ as in Gibbs & Taylor (2005).
#
# ### References
#
#    Adcock, T. A. A., & Taylor, P. H. (2009). Focusing of unidirectional wave groups on deep water: an approximate nonlinear Schrödinger equation-based model. *Proceedings of the Royal Society A: Mathematical, Physical and Engineering Sciences*, 465(2110), 3083-3102.
#
#    Gibbs, R. H., & Taylor, P. H. (2005). Formation of walls of water in ‘fully’nonlinear simulations. Applied Ocean Research, 27(3), 142-157.

# %% [markdown]
# ## RK4

# %%
## 4th-order explicit Runge-Kutta solver for time-independant ODE ##
def RK4(yt,h,f):
    k1=h*f(yt)
    k2=h*f(yt+0.5*k1)
    k3=h*f(yt+0.5*k2)
    k4=h*f(yt+k3)
    dy=(k1+2*k2+2*k3+k4)/6
    return yt+dy
#    return yt+k1

# %% [markdown]
# ## Settings for the equation

# %%
## Physical parameters ##
tp=12 #(s) peak period
grav=9.81 # (m/s^2) gravity acceleration at the earth's surface
w0=2*np.pi/tp # (s^-1) peak pulse
k0=(w0**2)/grav # (m^-1) peak wavenumber
lbda0=2*np.pi/k0 # (m) peak wavelength

# %%
## Domain ##
# Spatial #
dx=10; dX=2*np.sqrt(2)*k0*dx # Spatial discretization
Nx=2**12 # Number of points in space (=number of Fourier modes)
Nlbda=Nx*dx/lbda0 # Number of peak wavelength in the spatial domain
X_axis=np.arange(-dX*Nx/2,dX*Nx/2,dX)
# Temporal #
#Nper=2*1500 # Number of peak period in the temporal domain
Nper=65 # Number of peak period in the temporal domain
dt=0.14; dT=w0*dt # Temporal discretization
Nt=round((Nper+1)*tp/dt)
T_axis=np.arange(0,Nt*dT,dT)

# %%
dx,dt,2*np.max(X_axis)/(2*np.sqrt(2)*k0),w0,k0
# Out:
# (10, 0.14, 40940.000000008804, 0.5235987755982988, 0.027946552274009957)

# %%
## Checking ##
print(len(X_axis),Nx,dX)
print(Nlbda)
print(len(T_axis),Nt,dT)
print(Nper)
# Out:
# 4096 4096 0.7904478649494708
# 182.18319613070267
# 5657 5657 0.07330382858376185
# 65

# %% [markdown]
# ## Initialization

# %%
C=np.zeros((Nt,Nx),np.complex64) # Fourier modes for U

# %% [markdown]
# Start from a linearly back-propagated Gaussian wave packet :

# %%
## Back-propagated Gaussian packet ##
sig=2*np.sqrt(2)*5  # sig = 2sqrt(2)*LfkO
A=1.1*(2**0.25)/sig
phi0=2*np.pi*np.random.rand()  # uniform phase
U00=A*np.exp(-X_axis**2/(2*sig**2))*np.exp(1j*phi0)
C00=np.fft.fft(U00)
Delta_T=4*(-0.5*sig**2) # (-0.5*sig**2) corresponds to om0*tau for the article on GWP
                        # and crest velocities

OmNxdX=-(2*np.pi*np.fft.fftfreq(Nx,dX))**2    
                                    # -> This formula for the dispertion relation
                                    # for the envelope is true in the narrow-band limit
                                    # that is used for the NLSE
                                    # and in the reference frame
                                    # moving with the group-velocity
    
C0=C00*np.exp(-1j*OmNxdX*Delta_T)

U0=np.fft.ifft(C0)
C[0,:]=C0

# %%
plt.clf()
plt.plot(X_axis,np.abs(U0)/A,'r',label='Initial condition')
plt.plot(X_axis,np.abs(U00)/A,'--k',label='Linear focus corresponding to Initial condition')
plt.legend(bbox_to_anchor=(1, 1)); plt.xlabel("position"); plt.ylabel('amplitude of envelope')
#plt.xlim([-200,200]);
plt.xlim([-1000,1000]);
plt.grid(); plt.show()

# %%
Delta_T,Nt*dT,Delta_T/(2*np.pi),Delta_T/dT
# Out:
# (-400.00000000000006,
#  414.67975829834074,
#  -63.66197723675815,
#  -5456.740906007841)

# %% [markdown]
# Adcock and Taylor (2009) showed that $2^{1/4}$ and $2^{3/4}$ are important thresholds for the ratio (Spectral Amplitude)/(Spectral bandwidth) as far as the behaviour of the wave packet is concerned (actually $2^{1/4}$ is not a real threshold). The next line helps knowing in which region we are.

# %%
## Comparing sig*A, 2^(1/4) and 2^(3/4) ##
sig*A,[2**0.25,2**0.75]
# Out:
# (1.3081278265029932, [1.189207115002721, 1.681792830507429])

# %%
## Adimensional amplitude at linear focus a*k_p, H/L ##
print('LINEAR amplitude at linear focus')
print('ak_p='+str(A*np.sqrt(2)))
print('H/L='+str(A*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# LINEAR amplitude at linear focus
# ak_p=0.13081278265029933
# H/L=0.04163900195680173
# 1/7=0.14285714285714285

# %% [markdown]
# ## Defining the equation to be solved
# /!\ WARNING : if $N_x$ or $dX$ is changed, the equation must be redefined before solving.

# %%
## Function for integration of the NLSE in Fourier space ##
def NLS_spec(c_t):
    u_t=np.fft.ifft(c_t)
    c_prime_t=np.fft.fft((np.abs(u_t)**2)*u_t)
    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # original
#    return -1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # opposite sign
#    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t ) # only propagation

# %%
Nt,int(Nt/100)
# Out:
# (5657, 56)

# %% [markdown]
# ## Solving

# %%
## Integration of the NLSE ##
temps_depart=time.time()
for i in range(Nt-1):
    C[i+1,:]=RK4(C[i,:],dT,NLS_spec)
    if (i%int(Nt/100))==0:
        print('i/Nt='+str(int(100*i/Nt))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
temps_sim=time.time()-temps_depart
print('Numerical integration time = '+str(round(temps_sim,2))+'s')
# Out:
# i/Nt=0%, computing time = 0s
# i/Nt=0%, computing time = 0s
# i/Nt=1%, computing time = 1s
# i/Nt=2%, computing time = 1s
# i/Nt=3%, computing time = 1s
# i/Nt=4%, computing time = 1s
# i/Nt=5%, computing time = 2s
# i/Nt=6%, computing time = 2s
# i/Nt=7%, computing time = 2s
# i/Nt=8%, computing time = 3s
# i/Nt=9%, computing time = 3s
# i/Nt=10%, computing time = 3s
# i/Nt=11%, computing time = 4s
# i/Nt=12%, computing time = 4s
# i/Nt=13%, computing time = 4s
# i/Nt=14%, computing time = 5s
# i/Nt=15%, computing time = 5s
# i/Nt=16%, computing time = 5s
# i/Nt=17%, computing time = 5s
# i/Nt=18%, computing time = 6s
# i/Nt=19%, computing time = 6s
# i/Nt=20%, computing time = 6s
# i/Nt=21%, computing time = 7s
# i/Nt=22%, computing time = 7s
# i/Nt=23%, computing time = 7s
# i/Nt=24%, computing time = 8s
# i/Nt=25%, computing time = 8s
# i/Nt=26%, computing time = 8s
# i/Nt=27%, computing time = 8s
# i/Nt=28%, computing time = 9s
# i/Nt=29%, computing time = 9s
# i/Nt=30%, computing time = 9s
# i/Nt=31%, computing time = 10s
# i/Nt=32%, computing time = 10s
# i/Nt=33%, computing time = 10s
# i/Nt=34%, computing time = 10s
# i/Nt=35%, computing time = 11s
# i/Nt=36%, computing time = 11s
# i/Nt=37%, computing time = 11s
# i/Nt=38%, computing time = 12s
# i/Nt=39%, computing time = 12s
# i/Nt=40%, computing time = 12s
# i/Nt=41%, computing time = 12s
# i/Nt=42%, computing time = 13s
# i/Nt=43%, computing time = 13s
# i/Nt=44%, computing time = 13s
# i/Nt=45%, computing time = 14s
# i/Nt=46%, computing time = 14s
# i/Nt=47%, computing time = 14s
# i/Nt=48%, computing time = 14s
# i/Nt=49%, computing time = 15s
# i/Nt=50%, computing time = 15s
# i/Nt=51%, computing time = 15s
# i/Nt=52%, computing time = 16s
# i/Nt=53%, computing time = 16s
# i/Nt=54%, computing time = 16s
# i/Nt=55%, computing time = 17s
# i/Nt=56%, computing time = 17s
# i/Nt=57%, computing time = 17s
# i/Nt=58%, computing time = 17s
# i/Nt=59%, computing time = 18s
# i/Nt=60%, computing time = 18s
# i/Nt=61%, computing time = 18s
# i/Nt=62%, computing time = 18s
# i/Nt=63%, computing time = 19s
# i/Nt=64%, computing time = 19s
# i/Nt=65%, computing time = 19s
# i/Nt=66%, computing time = 20s
# i/Nt=67%, computing time = 20s
# i/Nt=68%, computing time = 20s
# i/Nt=69%, computing time = 20s
# i/Nt=70%, computing time = 21s
# i/Nt=71%, computing time = 21s
# i/Nt=72%, computing time = 21s
# i/Nt=73%, computing time = 22s
# i/Nt=74%, computing time = 22s
# i/Nt=75%, computing time = 22s
# i/Nt=76%, computing time = 22s
# i/Nt=77%, computing time = 23s
# i/Nt=78%, computing time = 23s
# i/Nt=79%, computing time = 23s
# i/Nt=80%, computing time = 23s
# i/Nt=81%, computing time = 24s
# i/Nt=82%, computing time = 24s
# i/Nt=83%, computing time = 24s
# i/Nt=84%, computing time = 25s
# i/Nt=85%, computing time = 25s
# i/Nt=86%, computing time = 25s
# i/Nt=87%, computing time = 25s
# i/Nt=88%, computing time = 26s
# i/Nt=89%, computing time = 26s
# i/Nt=90%, computing time = 26s
# i/Nt=91%, computing time = 27s
# i/Nt=92%, computing time = 27s
# i/Nt=93%, computing time = 27s
# i/Nt=94%, computing time = 27s
# i/Nt=95%, computing time = 28s
# i/Nt=96%, computing time = 28s
# i/Nt=97%, computing time = 28s
# i/Nt=98%, computing time = 29s
# i/Nt=98%, computing time = 29s
# Numerical integration time = 29.05s

# %%
amp_max_nonlin=np.max(np.abs(np.fft.ifft(C)))
## Adimensional amplitude at non-linear focus a*k_p, H/L ##
print('NONLINEAR amplitude at nonlinear focus')
print('ak_p='+str(amp_max_nonlin*np.sqrt(2)))
print('H/L='+str(amp_max_nonlin*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# NONLINEAR amplitude at nonlinear focus
# ak_p=0.16300159806808914
# H/L=0.05188502012882945
# 1/7=0.14285714285714285

# %% [markdown]
# ## Interpolation and cutting
# Interpolating in $x$-space and leaving the useless parts of data.

# %% [markdown]
# *In time* (cutting)

# %%
np.argmax(np.amax(np.abs(np.fft.ifft(C)[5000:,:]),axis=1))
# Out:
# 78

# %%
np.argmax(np.amax(np.abs(np.fft.ifft(C)[5000:,:]),axis=1))
# Out:
# 78

# %%
plt.clf()
plt.plot(np.amax(np.abs(np.fft.ifft(C)[5060:5100,:]),axis=1)/A)
plt.show()

# %%
np.amax(np.abs(np.fft.ifft(C)[5077,:]))/A,np.amax(np.abs(np.fft.ifft(C)[5078,:]))/A,np.amax(np.abs(np.fft.ifft(C)[5079,:]))/A,
# Out:
# (1.24606788649216, 1.2460681379862604, 1.2460677861164462)

# %%
#nt1=1648; nt2=5078;dnt=1
nt1=1648+2242-20; nt2=1648+2242+20; nt3=5078;dnt=1
nt1=1648; nt2=5078; nt3=5078;dnt=1
#(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/(2*np.pi),len(T_axis)
(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/(2*np.pi),len(T_axis)
# Out:
# (array([-4.00166667e+01, -4.00050000e+01, -3.99933333e+01, ...,
#         -2.33333333e-02, -1.16666667e-02,  0.00000000e+00]), 5657)

# %%
#t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/w0
t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/w0

# %% [markdown]
# *In space* (interpolating and cutting)

# %%
from scipy import interpolate

# %%
n=nt1;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.xlim(-200,200)
plt.show()

# %%
scale=300
dx_new=dx/scale; dX_new=dX/scale
#X_axis_new=np.arange(-dX*Nx/2,dX*Nx/2,dX_new)
X_axis_new=np.arange(-75,75,dX_new)

# %%
#x_axis=X_axis_new[nx1:nx2+1]/(2*np.sqrt(2)*k0)
x_axis=X_axis_new/(2*np.sqrt(2)*k0)

# %%
#int(Nx*scale),Nx*scale,len(X_axis_new),X_axis_new[0],X_axis_new[-1],X_axis_new[-2],dX*Nx/2,dX*Nx/2+dX_new
Nx,len(X_axis_new),X_axis_new[0],X_axis_new[-1]
# Out:
# (4096, 56930, -75.0, 74.99802167873139)

# %%
temps_depart=time.time()
U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64)
for n in range(nt1,nt2+1):
    tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:])),s=0)
    tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:])),s=0)
    U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)
temps_interp=time.time()-temps_depart

# %%
temps_interp/60,nt2-nt1+1
# Out:
# (1.642235767841339, 3431)

# %%
n=0;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.real(U_new[n,:]),'-r')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.imag(U_new[n,:]),'-r')
plt.xlim(-200,200)
#plt.xlim(-50,50)
#plt.xlim(-5,5)
#plt.xlim(50,60)
plt.show()

# %%
temps_depart=time.time()
# Recalculating the associated sea-surface elevation
eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
             *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )
temps_sse=time.time()-temps_depart

# %%
temps_sse,dt,nt2-nt1+1
# Out:
# (14.577113389968872, 0.14, 3431)

# %% [markdown]
# ## Crest velocities

# %%
par2om=-w0/(4*k0**2)
L=sig/(2*np.sqrt(2)*k0)
tau=L**2/par2om
c0=w0/k0
cg0=w0/(2*k0)
ccr_1ord=cg0+0.5*k0*par2om-c0
ccr_grad_1ord=(-c0+cg0)*k0*t_axis/tau
ccr_2ord=c0-cg0-0.5*k0*par2om
ccr_grad_2ord=k0*(1.5*par2om*k0+4*c0-4*cg0)*t_axis/tau
ccr_lapl_2ord=2*((c0-cg0+0.5*k0*par2om)*(t_axis/tau)**2-0.5*k0*par2om)*(k0)**2
Spread_x=np.sqrt(L**2+(L**(-2))*(par2om*t_axis)**2)
c_grad_expect=ccr_grad_1ord[:-2]/((k0*Spread_x[:-2])**2)+0.5*ccr_grad_2ord[:-2]/((k0*Spread_x[:-2])**4)
c_grad_expect1ord=ccr_grad_1ord[:-2]/((k0*Spread_x[:-2])**2)

# %%
from scipy.signal import argrelextrema

# %%
temps_depart=time.time()
extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
extrema=[]
for k in range(len(extrema2[0])):
    extrema.append([extrema2[1][k],extrema2[0][k]])
temps_extr2=time.time()-temps_depart

# %%
temps_extr2/60,len(extrema),nt2-nt1+1
# Out:
# (0.28796186844507854, 59231, 3431)

# %%
np.max(eta1*k0/(A*np.sqrt(2)))
# Out:
# 1.245654192827673

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=20
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=2400
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=10
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=24
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
temps_depart=time.time()
nmoy=15 # number of time-steps over which the mean velicity is computed
extr_speed1=np.zeros(len(extrema))
for m in range(len(extrema)):
    if (m%int(len(extrema)/100))==0:
        print('computing='+str(int(100*m/len(extrema)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    i=extrema[m][0]; n=extrema[m][1]
    signe=np.sign(eta1[i,n])
    if n<=nmoy:
        i2=False
        for m2 in range(m,len(extrema)):
            if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                    and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                i2=extrema[m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
    else:
        for m2 in range(len(extrema)):
            if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                    and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                i2=extrema[m-m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
temps_speed=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 0s
# computing=1%, computing time = 1s
# computing=2%, computing time = 2s
# computing=3%, computing time = 3s
# computing=4%, computing time = 3s
# computing=5%, computing time = 4s
# computing=6%, computing time = 5s
# computing=7%, computing time = 5s
# computing=8%, computing time = 6s
# computing=9%, computing time = 6s
# computing=10%, computing time = 7s
# computing=11%, computing time = 8s
# computing=12%, computing time = 8s
# computing=13%, computing time = 9s
# computing=14%, computing time = 10s
# computing=15%, computing time = 10s
# computing=16%, computing time = 11s
# computing=17%, computing time = 11s
# computing=18%, computing time = 12s
# computing=19%, computing time = 13s
# computing=20%, computing time = 13s
# computing=21%, computing time = 14s
# computing=22%, computing time = 14s
# computing=23%, computing time = 15s
# computing=24%, computing time = 16s
# computing=25%, computing time = 16s
# computing=26%, computing time = 17s
# computing=27%, computing time = 17s
# computing=28%, computing time = 18s
# computing=29%, computing time = 19s
# computing=30%, computing time = 19s
# computing=31%, computing time = 20s
# computing=32%, computing time = 20s
# computing=33%, computing time = 21s
# computing=34%, computing time = 22s
# computing=35%, computing time = 22s
# computing=36%, computing time = 23s
# computing=37%, computing time = 23s
# computing=38%, computing time = 24s
# computing=39%, computing time = 25s
# computing=40%, computing time = 25s
# computing=41%, computing time = 26s
# computing=42%, computing time = 27s
# computing=43%, computing time = 27s
# computing=44%, computing time = 28s
# computing=45%, computing time = 28s
# computing=46%, computing time = 29s
# computing=47%, computing time = 30s
# computing=48%, computing time = 30s
# computing=49%, computing time = 31s
# computing=50%, computing time = 31s
# computing=51%, computing time = 32s
# computing=52%, computing time = 33s
# computing=53%, computing time = 33s
# computing=54%, computing time = 34s
# computing=55%, computing time = 35s
# computing=56%, computing time = 35s
# computing=57%, computing time = 36s
# computing=58%, computing time = 36s
# computing=59%, computing time = 37s
# computing=60%, computing time = 38s
# computing=61%, computing time = 38s
# computing=62%, computing time = 39s
# computing=63%, computing time = 39s
# computing=64%, computing time = 40s
# computing=65%, computing time = 41s
# computing=66%, computing time = 41s
# computing=67%, computing time = 42s
# computing=68%, computing time = 42s
# computing=69%, computing time = 44s
# computing=70%, computing time = 44s
# computing=71%, computing time = 45s
# computing=72%, computing time = 45s
# computing=73%, computing time = 45s
# computing=74%, computing time = 47s
# computing=75%, computing time = 47s
# computing=76%, computing time = 48s
# computing=77%, computing time = 48s
# computing=78%, computing time = 50s
# computing=79%, computing time = 50s
# computing=80%, computing time = 51s
# computing=81%, computing time = 51s
# computing=82%, computing time = 53s
# computing=83%, computing time = 53s
# computing=84%, computing time = 53s
# computing=85%, computing time = 54s
# computing=86%, computing time = 54s
# computing=87%, computing time = 56s
# computing=88%, computing time = 56s
# computing=89%, computing time = 57s
# computing=90%, computing time = 57s
# computing=91%, computing time = 58s
# computing=92%, computing time = 59s
# computing=93%, computing time = 59s
# computing=94%, computing time = 60s
# computing=95%, computing time = 60s
# computing=96%, computing time = 61s
# computing=97%, computing time = 62s
# computing=98%, computing time = 62s
# computing=99%, computing time = 62s

# %%
temps_speed
# Out:
# 62.39877390861511

# %%
dt*dnt*nmoy/(2*np.pi/w0),dx_new/(nmoy*dt*dnt),(c0/2)/(L*k0)**2,(dx_new/(nmoy*dt*dnt))/((c0/2)/(L*k0)**2)
# Out:
# (0.17500000000000002,
#  0.015873015873015872,
#  0.37471439801555845,
#  0.042360304159854596)

# %%
n=100
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=100
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
n=2300
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=2300
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
n=20
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %% [markdown]
# #### Iteration for Fig1bis

# %%
nn=20; x_ccr=[]; ccr_adim=[]; t_adim=t_axis[nn]*k0*c0/(2*np.pi)

# %%
temps_depart=time.time()
DPHI=np.linspace(0,2*np.pi,num=25)
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # store the results
    for m in range(len(extrema)):
        if extrema[m][1]==nn:
            x_ccr.append(x_axis[extrema[m][0]]*k0/(2*np.pi))
            ccr_adim.append((extr_speed1[m]-c0/2)/c0)
temps_fig1bis=time.time()-temps_depart
# Out:
# Calculation 5% complete, time=0.0min
# Calculation 9% complete, time=0.0min
# Calculation 13% complete, time=0.0min
# Calculation 17% complete, time=0.1min
# Calculation 21% complete, time=0.1min
# Calculation 26% complete, time=0.1min
# Calculation 30% complete, time=0.1min
# Calculation 34% complete, time=0.2min
# Calculation 38% complete, time=0.2min
# Calculation 42% complete, time=0.2min
# Calculation 46% complete, time=0.3min
# Calculation 51% complete, time=0.3min
# Calculation 55% complete, time=0.3min
# Calculation 59% complete, time=0.3min
# Calculation 63% complete, time=0.4min
# Calculation 67% complete, time=0.4min
# Calculation 71% complete, time=0.4min
# Calculation 76% complete, time=0.5min
# Calculation 80% complete, time=0.5min
# Calculation 84% complete, time=0.5min
# Calculation 88% complete, time=0.5min
# Calculation 92% complete, time=0.6min
# Calculation 96% complete, time=0.6min
# Calculation 101% complete, time=0.6min

# %%
temps_fig1bis/60,len(DPHI)
# Out:
# (0.7018111348152161, 25)

# %%
x_ccr=np.array(x_ccr);ccr_adim=np.array(ccr_adim)

# %%
index=np.argsort(x_ccr)
x_ccr=x_ccr[index];ccr_adim=ccr_adim[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2)
           +(ccr_grad_2ord[nn]*x_axis+0.5*ccr_lapl_2ord[nn]*x_axis**2)/((k0*Spread_x[nn])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2))/c0,'--',color='grey')
ax.plot(x_ccr[6:],ccr_adim[6:],'-.k')
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[nn]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--',color='grey')
ax.plot(x_ccr[4:],ccr_adim[4:],'-.k')
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
np.savez('c_mes_L5_A0p13.npz',x_ccr=np.array(x_ccr),ccr_adim=np.array(ccr_adim),
         t_adim=t_adim,tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
tau*w0/(2*np.pi),t_adim
# Out:
# (-15.91549430918953, -11.083333333333336)

# %% [markdown]
# #### For Fig3 bis

# %%
c_grad_agg=[];t_grad_agg=[]

# %%
temps_depart=time.time()
DPHI=np.linspace(0,2*np.pi,num=4,endpoint=0)
#DPHI=np.array([0.25,0.75,1.63])*np.pi
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # position of the largest crest/trough in space, over time
    eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
    # criterion for having the largest crest/trough close enough to the center of the WP
    thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp) 
    
    # measuring the center gradient
    c_grad_mes=[]
    t_grad_mes=[]
    dist0=np.max(x_axis)*10**2
    LM=linear_model.LinearRegression()

    for n in range(len(t_axis)):
        if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
            and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
            t_grad_mes.append(t_axis[n])
        
            m0=0
            dist=dist0
            for m in range(len(extrema)):
                if (extrema[m][1]==n
                    and np.abs(x_axis[extrema[m][0]])<dist):
                    dist=np.abs(x_axis[extrema[m][0]])
                    m0=m
            
            y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
            X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
            c_grad_mes.append(LM.fit(X,y).coef_[1])
            del X, y

    c_=[c_grad_mes[0]]
    t_=[t_grad_mes[0]]
    for n in range(len(t_grad_mes)-1):
        if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
            c_.append(c_grad_mes[n+1])
            t_.append(t_grad_mes[n+1])
        else:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
            c_=[c_grad_mes[n+1]]
            t_=[t_grad_mes[n+1]]
        if n+1==len(t_grad_mes)-1:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
    
temps_fig3bis=time.time()-temps_depart
# Out:
# Calculation 34% complete, time=22.min
# Calculation 67% complete, time=26.min
# Calculation 101% complete, time=29.min

# %%
temps_fig3bis/60,len(DPHI)
# Out:
# (33.340909922122954, 4)

# %%
DPHI/np.pi
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
t_grad_agg=np.array(t_grad_agg); c_grad_agg=np.array(c_grad_agg)

# %%
index=np.argsort(t_grad_agg)
t_grad_agg=t_grad_agg[index];c_grad_agg=c_grad_agg[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
np.savez('c_grad_L5_A0p13_0.npz',t_grad_agg=t_grad_agg,c_grad_agg=c_grad_agg,
         tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_grad_agg/np.abs(tau),
        lowess(c_grad_agg*L*L*k0*k0/(c0*k0), t_grad_agg/np.abs(tau),
               frac=1./10, it=3, return_sorted=False),
        '-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
n_min=np.argmin(lowess(c_grad_agg*L*L*k0*k0/(c0*k0), t_grad_agg/np.abs(tau),
               frac=1./12, it=3, return_sorted=False))
t_min_adim=t_grad_agg[n_min]/np.abs(tau)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_grad_agg/np.abs(tau),c_grad_agg*L*L*k0*k0/(c0*k0),'-r')
ax.plot([t_min_adim,t_min_adim],[-1,1],'--k')
#ax.set_xlim([-2,0])
ax.set_ylim([-.5,0])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
t_axis[2242],t_grad_agg[n_min]
# Out:
# (-166.3200000000001, -166.3900000000001)

# %%
n=2300
spid=0
for m in range(len(extrema)):
    if extrema[m][1]==n:
        diff=(extr_speed1[m]-spid)/(dx_new/(nmoy*dt*dnt))
        spid=extr_speed1[m]
        print('velocity='+str(spid)+', velocity difference / precision ='+str(diff))
# Out:
# velocity=14.460317460288826, velocity difference / precision =910.999999998196
# velocity=13.301587301560966, velocity difference / precision =-72.99999999985516
# velocity=12.571428571403711, velocity difference / precision =-45.99999999990707
# velocity=13.555555555528745, velocity difference / precision =61.999999999877126
# velocity=10.904761904740333, velocity difference / precision =-166.99999999966994
# velocity=9.301587301568905, velocity difference / precision =-100.9999999998
# velocity=8.53968253966565, velocity difference / precision =-47.99999999990504
# velocity=7.95238095236522, velocity difference / precision =-36.99999999992707
# velocity=7.412698412683767, velocity difference / precision =-33.99999999993156
# velocity=7.126984126970038, velocity difference / precision =-17.99999999996491
# velocity=7.047619047605113, velocity difference / precision =-4.999999999990302
# velocity=6.984126984113188, velocity difference / precision =-3.9999999999912568
# velocity=6.857142857129258, velocity difference / precision =-7.9999999999876055
# velocity=6.698412698399622, velocity difference / precision =-9.999999999967063
# velocity=6.555555555542501, velocity difference / precision =-8.999999999998625
# velocity=6.3333333333209145, velocity difference / precision =-13.999999999959943
# velocity=6.047619047607159, velocity difference / precision =-17.999999999966587

# %%
temps_depart=time.time()

c_grad_mes_spl=np.zeros(len(t_axis)-2)
c_spl=[]
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()
xnew=np.arange(-np.pi/k0,np.pi/k0,(2*np.pi/k0)/50)
for n in range(len(t_axis)-2):
    if (n%int((len(t_axis)-2)/100))==0:
        print('computing='+str(int(100*n/(len(t_axis)-2)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    m0=0
    dist=dist0
    for m in range(len(extrema)):
        if (extrema[m][1]==n
            and np.abs(x_axis[extrema[m][0]])<dist):
            dist=np.abs(x_axis[extrema[m][0]])
            m0=m
            
    y=np.array([  
                extr_speed1[m0-2] , 
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1],
                extr_speed1[m0+2]  
               ])
    
    x=np.array([ 
                [x_axis[extrema[m0-2][0]]],
                [x_axis[extrema[m0-1][0]]],
                [x_axis[extrema[m0][0]]],
                [x_axis[extrema[m0+1][0]]],
                [x_axis[extrema[m0+2][0]]]
               ])
    
    interpol=interpolate.splrep(x,y)
    ynew=interpolate.splev(xnew,interpol,der=0)
    
    c_grad_mes_spl[n]=LM.fit(np.array([xnew]).T,ynew).coef_[0]
    c_spl.append(ynew)
    del x, y, ynew
temps_grad=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 2s
# computing=1%, computing time = 4s
# computing=2%, computing time = 5s
# computing=3%, computing time = 7s
# computing=4%, computing time = 9s
# computing=5%, computing time = 10s
# computing=6%, computing time = 12s
# computing=7%, computing time = 14s
# computing=8%, computing time = 16s
# computing=9%, computing time = 17s
# computing=10%, computing time = 19s
# computing=11%, computing time = 21s
# computing=12%, computing time = 22s
# computing=13%, computing time = 24s
# computing=14%, computing time = 26s
# computing=15%, computing time = 28s
# computing=16%, computing time = 29s
# computing=17%, computing time = 31s
# computing=18%, computing time = 33s
# computing=19%, computing time = 34s
# computing=20%, computing time = 36s
# computing=21%, computing time = 38s
# computing=22%, computing time = 40s
# computing=23%, computing time = 41s
# computing=24%, computing time = 43s
# computing=25%, computing time = 45s
# computing=26%, computing time = 47s
# computing=27%, computing time = 49s
# computing=28%, computing time = 50s
# computing=29%, computing time = 52s
# computing=30%, computing time = 54s
# computing=31%, computing time = 56s
# computing=32%, computing time = 58s
# computing=33%, computing time = 59s
# computing=34%, computing time = 61s
# computing=35%, computing time = 63s
# computing=36%, computing time = 65s
# computing=37%, computing time = 66s
# computing=38%, computing time = 68s
# computing=39%, computing time = 70s
# computing=40%, computing time = 71s
# computing=41%, computing time = 73s
# computing=42%, computing time = 75s
# computing=43%, computing time = 76s
# computing=44%, computing time = 78s
# computing=45%, computing time = 80s
# computing=46%, computing time = 82s
# computing=47%, computing time = 83s
# computing=48%, computing time = 85s
# computing=49%, computing time = 87s
# computing=50%, computing time = 88s
# computing=51%, computing time = 90s
# computing=52%, computing time = 92s
# computing=53%, computing time = 93s
# computing=54%, computing time = 95s
# computing=55%, computing time = 97s
# computing=56%, computing time = 98s
# computing=57%, computing time = 100s
# computing=58%, computing time = 102s
# computing=59%, computing time = 104s
# computing=60%, computing time = 105s
# computing=61%, computing time = 107s
# computing=62%, computing time = 109s
# computing=63%, computing time = 110s
# computing=64%, computing time = 112s
# computing=65%, computing time = 114s
# computing=66%, computing time = 115s
# computing=67%, computing time = 117s
# computing=68%, computing time = 119s
# computing=69%, computing time = 121s
# computing=70%, computing time = 122s
# computing=71%, computing time = 124s
# computing=72%, computing time = 126s
# computing=73%, computing time = 127s
# computing=74%, computing time = 129s
# computing=75%, computing time = 131s
# computing=76%, computing time = 132s
# computing=77%, computing time = 134s
# computing=78%, computing time = 136s
# computing=79%, computing time = 138s
# computing=80%, computing time = 140s
# computing=81%, computing time = 141s
# computing=82%, computing time = 143s
# computing=83%, computing time = 145s
# computing=84%, computing time = 147s
# computing=85%, computing time = 148s
# computing=86%, computing time = 150s
# computing=87%, computing time = 152s
# computing=88%, computing time = 153s
# computing=89%, computing time = 155s
# computing=90%, computing time = 157s
# computing=91%, computing time = 159s
# computing=92%, computing time = 160s
# computing=93%, computing time = 162s
# computing=94%, computing time = 164s
# computing=95%, computing time = 166s
# computing=96%, computing time = 167s
# computing=97%, computing time = 169s
# computing=98%, computing time = 171s
# computing=99%, computing time = 172s

# %%
# position of the largest crest/trough in space, over time
eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
# criterion for having the largest crest/trough close enough to the center of the WP
thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp)

# %%
temps_depart=time.time()
c_grad_mes=[]
t_grad_mes=[]
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()

for n in range(len(t_axis)):
#    if (n%int((len(t_axis)-2)/100))==0:
#        print('computing='+str(int(100*n/(len(t_axis)-2)))
#    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    
    if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
        and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
        t_grad_mes.append(t_axis[n])
        
        m0=0
        dist=dist0
        for m in range(len(extrema)):
            if (extrema[m][1]==n
                and np.abs(x_axis[extrema[m][0]])<dist):
                dist=np.abs(x_axis[extrema[m][0]])
                m0=m
            
        y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
        X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
        c_grad_mes.append(LM.fit(X,y).coef_[1])
        del X, y
temps_grad=time.time()-temps_depart

# %%
c_grad_agg=[] # "agg" stands for "agglomerate"
t_grad_agg=[]
c_=[c_grad_mes[0]]
t_=[t_grad_mes[0]]
for n in range(len(t_grad_mes)-1):
    if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
        c_.append(c_grad_mes[n+1])
        t_.append(t_grad_mes[n+1])
    else:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))
        c_=[c_grad_mes[n+1]]
        t_=[t_grad_mes[n+1]]
    if n+1==len(t_grad_mes)-1:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect1ord*L*L*k0*k0/(c0*k0),'--k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect1ord*L*L*k0*k0/(c0*k0),'--k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
ccr_grad_1ord_=(-c0+cg0)*k0*np.array(t_grad_agg)/tau
Spread_x_=np.sqrt(L**2+(L**(-2))*(par2om*np.array(t_grad_agg))**2)
c_grad_expect_=ccr_grad_1ord_/((k0*Spread_x_)**2)

# %%
A*np.sqrt(2),4*A
# Out:
# (0.13081278265029933, 0.3699944227116344)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
tsurtau=t_axis[:-2]/tau
#ax.plot(tsurtau,c_grad_expect*(1+5*A*np.sqrt(2)*(tsurtau/(1+tsurtau**2))**2 )*L*L*k0*k0/(c0*k0),'--k')
tsurtau_=np.array(t_grad_agg)/tau
ax.plot(-tsurtau_,np.array(c_grad_agg)/c_grad_expect_-1)
#ax.plot(-tsurtau_,(1-tsurtau_*4*A))
ax.plot(-tsurtau_,3.3*tsurtau_*np.exp(-tsurtau_/0.6))
#ax.plot(-tsurtau_,(tsurtau_/(1+tsurtau_**2))*np.pi*2*np.sqrt(2)*A*np.sqrt(2))
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
#ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
#plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %% [markdown]
# --------------
# Computing the amplitude over time

# %%
A_adim=np.amax(np.abs(U_new),axis=1)

# %% [markdown]
# Computing the width at focus

# %%
def gauss(x, *p):
    a, mu, sigma = p
    return a*np.exp(-(x-mu)**2/(2*sigma**2))
from scipy.optimize import curve_fit
p0=[1,0,1]

# %%
fit=curve_fit(gauss,x_axis,np.abs(U_new[-1,:]),p0=p0)
L_foc=fit[0][2]
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py:779: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
k0*L_foc
# Out:
# 3.1946318392109436

# %% [markdown]
# --------------
# ### Making the prediction

# %%
def gradient_fit( time , t0 , Tau ):
    return 2*((time-t0)/(Tau**2+(time-t0)**2))

def gradient_fit_addNL( time , t0 , Tau , addNL ):
    return 2*addNL*((time-t0)/(Tau**2+(time-t0)**2))

def gradient_fit22( time , t0 , Tau ):
    return 2*((time-t0)/(Tau**2+(time-t0)**2))*( 1-3.25/((k0*c0*Tau/4)*(1+((time-t0)/Tau)**2)) )

# %%
len(t_grad_agg)
# Out:
# 40

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)

nstart=9
Nts=len(t_grad_agg)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts)
tau_abs=np.zeros(Nts)
A_ratio=np.zeros(Nts)
L_estim=np.zeros(Nts)
cov=np.full((Nts,2,2),np.inf)

for nend in range(nstart+3,Nts):
    n=nend-nstart-3
#    popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
#                       ,sigma=STD_FIT*np.ones(nend-nstart))
    popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
                       ,sigma=STD_FIT*np.ones(nend-nstart),bounds=([-np.inf,1/w0],[np.inf,40000/w0]))
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'.b',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([1,4])
ax.set_xlim([-30,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([0,5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
#ne=nstart+1600
ne=39
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'.k',markersize=1)
ax.plot(np.array(t_grad_agg)[nstart:ne]/np.abs(tau),np.array(c_grad_agg)[nstart:ne]*L*L*k0*k0/(c0*k0),'r',markersize=1)
#ax.plot(t_axis[nstart:ne]/np.abs(tau),gradient_fit22(t_axis[nstart:ne],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':k',markersize=1)
ax.plot(np.array(t_grad_agg)[nstart:]/np.abs(tau),
        gradient_fit(np.array(t_grad_agg)[nstart:],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':g',linewidth=2)
#ax.set_xlim([-2,1])
ax.set_ylim([-2,0.01])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)

nstart=9
Nts=len(t_grad_agg)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts)
tau_abs=np.zeros(Nts)
A_ratio=np.zeros(Nts)
L_estim=np.zeros(Nts)
cov=np.full((Nts,2,2),np.inf)

for nend in range(nstart+3,Nts):
    n=nend-nstart-3
#    popt, pcov = curve_fit(gradient_fit, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
#                       ,sigma=STD_FIT*np.ones(nend-nstart))
    popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
                       ,sigma=STD_FIT*np.ones(nend-nstart),bounds=([-np.inf,1/w0],[np.inf,40000/w0]))
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'.b',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([1,3])
ax.set_xlim([-30,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([0,5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
#ne=nstart+1600
ne=35
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'.k',markersize=1)
ax.plot(np.array(t_grad_agg)[nstart:ne]/np.abs(tau),np.array(c_grad_agg)[nstart:ne]*L*L*k0*k0/(c0*k0),'r',markersize=1)
#ax.plot(t_axis[nstart:ne]/np.abs(tau),gradient_fit22(t_axis[nstart:ne],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':k',markersize=1)
ax.plot(np.array(t_grad_agg)[nstart:]/np.abs(tau),
        gradient_fit(np.array(t_grad_agg)[nstart:],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':g',linewidth=2)
#ax.set_xlim([-2,1])
ax.set_ylim([-1,0.01])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %% [markdown]
# ### For fig4bis

# %%
temps_depart=time.time()

N4=4*44

TFOC=[]
TAU_ABS=[]
A_RATIO=[]
L_ESTIM=[]
COV=[]
T_GRAD=[]
C_GRAD=[]

DPHI=np.linspace(0,np.pi,num=N4,endpoint=0)
#DPHI=np.array([0.25,0.75,1.63])*np.pi
STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)
avancement=0
for l in range(N4):
    if(100*DPHI[l]/DPHI[-1])>avancement:
        avancement=int(100*DPHI[l]/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*DPHI[l]))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*DPHI[l]))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # position of the largest crest/trough in space, over time
    eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
    # criterion for having the largest crest/trough close enough to the center of the WP
    thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp) 
    
    # measuring the center gradient
    c_grad_mes=[]
    t_grad_mes=[]
    dist0=np.max(x_axis)*10**2
    LM=linear_model.LinearRegression()

    for n in range(len(t_axis)):
        if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
            and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
            t_grad_mes.append(t_axis[n])
        
            m0=0
            dist=dist0
            for m in range(len(extrema)):
                if (extrema[m][1]==n
                    and np.abs(x_axis[extrema[m][0]])<dist):
                    dist=np.abs(x_axis[extrema[m][0]])
                    m0=m
            
            y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
            X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
            c_grad_mes.append(LM.fit(X,y).coef_[1])
            del X, y

    c_grad_agg=[]
    t_grad_agg=[]
    c_=[c_grad_mes[0]]
    t_=[t_grad_mes[0]]
    for n in range(len(t_grad_mes)-1):
        if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
            c_.append(c_grad_mes[n+1])
            t_.append(t_grad_mes[n+1])
        else:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
            c_=[c_grad_mes[n+1]]
            t_=[t_grad_mes[n+1]]
        if n+1==len(t_grad_mes)-1:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))

    nstart=9
    Nts=len(t_grad_agg)
    # tfoc, A_ratio and L are predicted values based on the best fit
    tfoc=np.zeros(Nts)
    tau_abs=np.zeros(Nts)
    A_ratio=np.zeros(Nts)
    L_estim=np.zeros(Nts)
    cov=np.full((Nts,2,2),np.inf)

    for nend in range(nstart+3,Nts):
        n=nend-nstart-3
    #    popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
    #                       ,sigma=STD_FIT*np.ones(nend-nstart))
        popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
                       ,sigma=STD_FIT*np.ones(nend-nstart),bounds=([-np.inf,1/w0],[np.inf,40000/w0]))
        tfoc[nend]=popt[0]
        tau_abs[nend]=np.abs(popt[1])
        L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
        A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
        cov[nend,:,:]=pcov
    
    TFOC.append(tfoc)
    TAU_ABS.append(tau_abs)
    A_RATIO.append(A_ratio)
    L_ESTIM.append(L_estim)
    COV.append(cov)
    T_GRAD.append(np.array(t_grad_agg))
    C_GRAD.append(np.array(c_grad_agg))
    
temps_fig4bis=time.time()-temps_depart
# Out:
# Calculation 1% complete, time=3.3min
# Calculation 2% complete, time=6.6min
# Calculation 3% complete, time=13.min
# Calculation 4% complete, time=20.min
# Calculation 5% complete, time=26.min
# Calculation 6% complete, time=30.min
# Calculation 7% complete, time=36.min
# Calculation 8% complete, time=43.min
# Calculation 9% complete, time=50.min
# Calculation 10% complete, time=53.min
# Calculation 11% complete, time=60.min
# Calculation 12% complete, time=66.min
# Calculation 13% complete, time=73.min
# Calculation 14% complete, time=77.min
# Calculation 15% complete, time=83.min
# Calculation 16% complete, time=90.min
# Calculation 17% complete, time=96.min
# Calculation 18% complete, time=100min
# Calculation 19% complete, time=106min
# Calculation 20% complete, time=113min
# Calculation 21% complete, time=120min
# Calculation 22% complete, time=123min
# Calculation 23% complete, time=130min
# Calculation 24% complete, time=136min
# Calculation 25% complete, time=143min
# Calculation 26% complete, time=146min
# Calculation 27% complete, time=153min
# Calculation 28% complete, time=160min
# Calculation 29% complete, time=163min
# Calculation 30% complete, time=170min
# Calculation 31% complete, time=176min
# Calculation 32% complete, time=183min
# Calculation 33% complete, time=190min
# Calculation 34% complete, time=193min
# Calculation 35% complete, time=200min
# Calculation 36% complete, time=206min
# Calculation 37% complete, time=213min
# Calculation 38% complete, time=216min
# Calculation 39% complete, time=223min
# Calculation 40% complete, time=229min
# Calculation 41% complete, time=236min
# Calculation 42% complete, time=239min
# Calculation 43% complete, time=246min
# Calculation 44% complete, time=253min
# Calculation 45% complete, time=259min
# Calculation 46% complete, time=263min
# Calculation 47% complete, time=269min
# Calculation 48% complete, time=276min
# Calculation 49% complete, time=283min
# Calculation 50% complete, time=286min
# Calculation 51% complete, time=293min
# Calculation 52% complete, time=299min
# Calculation 53% complete, time=306min
# Calculation 54% complete, time=309min
# Calculation 55% complete, time=316min
# Calculation 56% complete, time=323min
# Calculation 57% complete, time=326min
# Calculation 58% complete, time=333min
# Calculation 59% complete, time=339min
# Calculation 60% complete, time=346min
# Calculation 61% complete, time=353min
# Calculation 62% complete, time=356min
# Calculation 63% complete, time=363min
# Calculation 64% complete, time=370min
# Calculation 65% complete, time=376min
# Calculation 66% complete, time=380min
# Calculation 67% complete, time=386min
# Calculation 68% complete, time=393min
# Calculation 69% complete, time=400min
# Calculation 70% complete, time=403min
# Calculation 71% complete, time=410min
# Calculation 72% complete, time=417min
# Calculation 73% complete, time=424min
# Calculation 74% complete, time=427min
# Calculation 75% complete, time=434min
# Calculation 76% complete, time=440min
# Calculation 77% complete, time=447min
# Calculation 78% complete, time=451min
# Calculation 79% complete, time=457min
# Calculation 80% complete, time=464min
# Calculation 81% complete, time=471min
# Calculation 82% complete, time=474min
# Calculation 83% complete, time=481min
# Calculation 84% complete, time=487min
# Calculation 85% complete, time=491min
# Calculation 86% complete, time=497min
# Calculation 87% complete, time=504min
# Calculation 88% complete, time=511min
# Calculation 89% complete, time=517min
# Calculation 90% complete, time=521min
# Calculation 91% complete, time=528min
# Calculation 92% complete, time=534min
# Calculation 93% complete, time=537min
# Calculation 94% complete, time=544min
# Calculation 95% complete, time=551min
# Calculation 96% complete, time=558min
# Calculation 97% complete, time=564min
# Calculation 98% complete, time=568min
# Calculation 99% complete, time=574min
# Calculation 100% complete, time=581min

# %%
np.savez('fig4bis.npz',TFOC=TFOC,TAU_ABS=TAU_ABS,A_RATIO=A_RATIO,
         L_ESTIM=L_ESTIM,COV=COV,T_GRAD=T_GRAD,C_GRAD=C_GRAD,tau=tau)

# %%
np.savez('fig4bisAadim.npz',t_axis=t_axis,A_adim=A_adim,L_foc=L_foc)

# %%
DPHI/np.pi
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
temps_fig4bis/60
# Out:
# 14.52747802734375

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
for l in range(N4):
    ax.plot(T_GRAD[l][nstart+2:nend]*w0/(2*np.pi),TFOC[l][nstart+2:nend]*c0*k0/(2*np.pi),'.',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
for l in range(N4):
    ax.plot(T_GRAD[l][nstart+2:nend]*w0/(2*np.pi),A_RATIO[l][nstart+2:nend],'.',label='Estimation')
ax.set_ylim([1,14])
ax.set_xlim([-30,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
A_RATIO[0][nstart+7]
# Out:
# 2.815195008851014

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
for l in range(N4):
    ax.plot(T_GRAD[l][nstart+2:nend]*w0/(2*np.pi),k0*L_ESTIM[l][nstart+2:nend],'.',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([0,5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()
