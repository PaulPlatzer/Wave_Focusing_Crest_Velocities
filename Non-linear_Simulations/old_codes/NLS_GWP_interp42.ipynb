# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn import linear_model
from scipy.optimize import curve_fit

# %% [markdown]
# # Solving the Non-Linear Schrödinger Equation
#
# In the reference frame moving with the group velocity of waves, the Non-Linear Schrödinger equation for the envelope $u$ of 1D deep-water ocean surgace gravity waves is
# $$i \partial_t u =\frac{\omega_0}{8k_0^2}\partial_{xx} u+\frac{1}{2}\omega_0 k_0^2 |u|^2 u \, , $$
#
# where $\omega_0$ and $k_0$ are the peak pulse and wavenumber of the wave field which is represented as the real part of $u(x,t)\exp i\left(\omega_0 t -k_0 x \right)$, where $x$ is position and $t$ time.
#
# This equation can be non-dimensionalized setting $T=\omega_0 t$, $X=2\sqrt{2}k_0 x$, $U= \frac{k_0}{\sqrt{2}} u$, giving
#
# $$ i\partial_T U = \partial_{XX} U + |U|^2U \, . $$
#
# It will be solved using a pseudo-spectral scheme (see https://en.wikipedia.org/wiki/Pseudo-spectral_method) as is done in Adcock & Taylor (2009, see section 2 for details on the equation and section 3 for details concerning the numerical integration). The shape of the Gaussian wavenumber spectrum is fitted to a JONSWAP spectrum with $\gamma=3.3$ as in Gibbs & Taylor (2005).
#
# ### References
#
#    Adcock, T. A. A., & Taylor, P. H. (2009). Focusing of unidirectional wave groups on deep water: an approximate nonlinear Schrödinger equation-based model. *Proceedings of the Royal Society A: Mathematical, Physical and Engineering Sciences*, 465(2110), 3083-3102.
#
#    Gibbs, R. H., & Taylor, P. H. (2005). Formation of walls of water in ‘fully’nonlinear simulations. Applied Ocean Research, 27(3), 142-157.

# %% [markdown]
# ## RK4

# %%
## 4th-order explicit Runge-Kutta solver for time-independant ODE ##
def RK4(yt,h,f):
    k1=h*f(yt)
    k2=h*f(yt+0.5*k1)
    k3=h*f(yt+0.5*k2)
    k4=h*f(yt+k3)
    dy=(k1+2*k2+2*k3+k4)/6
    return yt+dy
#    return yt+k1

# %% [markdown]
# ## Settings for the equation

# %%
## Physical parameters ##
tp=12 #(s) peak period
grav=9.81 # (m/s^2) gravity acceleration at the earth's surface
w0=2*np.pi/tp # (s^-1) peak pulse
k0=(w0**2)/grav # (m^-1) peak wavenumber
lbda0=2*np.pi/k0 # (m) peak wavelength

# %%
## Domain ##
# Spatial #
dx=10; dX=2*np.sqrt(2)*k0*dx # Spatial discretization
Nx=2**12 # Number of points in space (=number of Fourier modes)
Nlbda=Nx*dx/lbda0 # Number of peak wavelength in the spatial domain
X_axis=np.arange(-dX*Nx/2,dX*Nx/2,dX)
# Temporal #
#Nper=2*1500 # Number of peak period in the temporal domain
Nper=65 # Number of peak period in the temporal domain
dt=0.14; dT=w0*dt # Temporal discretization
Nt=round((Nper+1)*tp/dt)
T_axis=np.arange(0,Nt*dT,dT)

# %%
dx,dt,2*np.max(X_axis)/(2*np.sqrt(2)*k0),w0,k0
# Out:
# (10, 0.14, 40940.000000008804, 0.5235987755982988, 0.027946552274009957)

# %%
## Checking ##
print(len(X_axis),Nx,dX)
print(Nlbda)
print(len(T_axis),Nt,dT)
print(Nper)
# Out:
# 4096 4096 0.7904478649494708
# 182.18319613070267
# 5657 5657 0.07330382858376185
# 65

# %% [markdown]
# ## Initialization

# %%
C=np.zeros((Nt,Nx),np.complex64) # Fourier modes for U

# %% [markdown]
# Start from a linearly back-propagated Gaussian wave packet :

# %%
## Back-propagated Gaussian packet ##
sig=2*np.sqrt(2)*5  # sig = 2sqrt(2)*LfkO
A=1.8*(2**0.25)/sig
#phi0=2*np.pi*np.random.rand()  # uniform phase
phi0=0  # uniform phase
U00=A*np.exp(-X_axis**2/(2*sig**2))*np.exp(1j*phi0)
C00=np.fft.fft(U00)
Delta_T=4*(-0.5*sig**2) # (-0.5*sig**2) corresponds to om0*tau for the article on GWP
                        # and crest velocities

OmNxdX=-(2*np.pi*np.fft.fftfreq(Nx,dX))**2    
                                    # -> This formula for the dispertion relation
                                    # for the envelope is true in the narrow-band limit
                                    # that is used for the NLSE
                                    # and in the reference frame
                                    # moving with the group-velocity
    
C0=C00*np.exp(-1j*OmNxdX*Delta_T)

U0=np.fft.ifft(C0)
C[0,:]=C0

# %%
plt.clf()
plt.plot(X_axis,np.abs(U0)/A,'r',label='Initial condition')
plt.plot(X_axis,np.abs(U00)/A,'--k',label='Linear focus corresponding to Initial condition')
plt.legend(bbox_to_anchor=(1, 1)); plt.xlabel("position"); plt.ylabel('amplitude of envelope')
#plt.xlim([-200,200]);
plt.xlim([-1000,1000]);
plt.grid(); plt.show()

# %%
Delta_T,Nt*dT,Delta_T/(2*np.pi),Delta_T/dT
# Out:
# (-400.00000000000006,
#  414.67975829834074,
#  -63.66197723675815,
#  -5456.740906007841)

# %% [markdown]
# Adcock and Taylor (2009) showed that $2^{1/4}$ and $2^{3/4}$ are important thresholds for the ratio (Spectral Amplitude)/(Spectral bandwidth) as far as the behaviour of the wave packet is concerned (actually $2^{1/4}$ is not a real threshold). The next line helps knowing in which region we are.

# %%
## Comparing sig*A, 2^(1/4) and 2^(3/4) ##
sig*A,[2**0.25,2**0.75]
# Out:
# (2.1405728070048977, [1.189207115002721, 1.681792830507429])

# %%
## Adimensional amplitude at linear focus a*k_p, H/L ##
print('LINEAR amplitude at linear focus')
print('ak_p='+str(A*np.sqrt(2)))
print('H/L='+str(A*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# LINEAR amplitude at linear focus
# ak_p=0.21405728070048977
# H/L=0.06813654865658463
# 1/7=0.14285714285714285

# %% [markdown]
# ## Defining the equation to be solved
# /!\ WARNING : if $N_x$ or $dX$ is changed, the equation must be redefined before solving.

# %%
## Function for integration of the NLSE in Fourier space ##
def NLS_spec(c_t):
    u_t=np.fft.ifft(c_t)
    c_prime_t=np.fft.fft((np.abs(u_t)**2)*u_t)
    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # original
#    return -1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # opposite sign
#    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t ) # only propagation

# %%
Nt,int(Nt/100)
# Out:
# (5657, 56)

# %% [markdown]
# ## Solving

# %%
## Integration of the NLSE ##
temps_depart=time.time()
for i in range(Nt-1):
    C[i+1,:]=RK4(C[i,:],dT,NLS_spec)
    if (i%int(Nt/100))==0:
        print('i/Nt='+str(int(100*i/Nt))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
temps_sim=time.time()-temps_depart
print('Numerical integration time = '+str(round(temps_sim,2))+'s')
# Out:
# i/Nt=0%, computing time = 0s
# i/Nt=0%, computing time = 0s
# i/Nt=1%, computing time = 1s
# i/Nt=2%, computing time = 1s
# i/Nt=3%, computing time = 1s
# i/Nt=4%, computing time = 2s
# i/Nt=5%, computing time = 2s
# i/Nt=6%, computing time = 2s
# i/Nt=7%, computing time = 2s
# i/Nt=8%, computing time = 3s
# i/Nt=9%, computing time = 3s
# i/Nt=10%, computing time = 3s
# i/Nt=11%, computing time = 4s
# i/Nt=12%, computing time = 4s
# i/Nt=13%, computing time = 4s
# i/Nt=14%, computing time = 4s
# i/Nt=15%, computing time = 5s
# i/Nt=16%, computing time = 5s
# i/Nt=17%, computing time = 5s
# i/Nt=18%, computing time = 6s
# i/Nt=19%, computing time = 6s
# i/Nt=20%, computing time = 6s
# i/Nt=21%, computing time = 7s
# i/Nt=22%, computing time = 7s
# i/Nt=23%, computing time = 7s
# i/Nt=24%, computing time = 7s
# i/Nt=25%, computing time = 8s
# i/Nt=26%, computing time = 8s
# i/Nt=27%, computing time = 8s
# i/Nt=28%, computing time = 9s
# i/Nt=29%, computing time = 9s
# i/Nt=30%, computing time = 9s
# i/Nt=31%, computing time = 9s
# i/Nt=32%, computing time = 10s
# i/Nt=33%, computing time = 10s
# i/Nt=34%, computing time = 10s
# i/Nt=35%, computing time = 11s
# i/Nt=36%, computing time = 11s
# i/Nt=37%, computing time = 11s
# i/Nt=38%, computing time = 11s
# i/Nt=39%, computing time = 12s
# i/Nt=40%, computing time = 12s
# i/Nt=41%, computing time = 12s
# i/Nt=42%, computing time = 13s
# i/Nt=43%, computing time = 13s
# i/Nt=44%, computing time = 13s
# i/Nt=45%, computing time = 13s
# i/Nt=46%, computing time = 14s
# i/Nt=47%, computing time = 14s
# i/Nt=48%, computing time = 14s
# i/Nt=49%, computing time = 15s
# i/Nt=50%, computing time = 15s
# i/Nt=51%, computing time = 15s
# i/Nt=52%, computing time = 15s
# i/Nt=53%, computing time = 16s
# i/Nt=54%, computing time = 16s
# i/Nt=55%, computing time = 16s
# i/Nt=56%, computing time = 17s
# i/Nt=57%, computing time = 17s
# i/Nt=58%, computing time = 17s
# i/Nt=59%, computing time = 17s
# i/Nt=60%, computing time = 18s
# i/Nt=61%, computing time = 18s
# i/Nt=62%, computing time = 18s
# i/Nt=63%, computing time = 19s
# i/Nt=64%, computing time = 19s
# i/Nt=65%, computing time = 19s
# i/Nt=66%, computing time = 19s
# i/Nt=67%, computing time = 20s
# i/Nt=68%, computing time = 20s
# i/Nt=69%, computing time = 20s
# i/Nt=70%, computing time = 21s
# i/Nt=71%, computing time = 21s
# i/Nt=72%, computing time = 21s
# i/Nt=73%, computing time = 21s
# i/Nt=74%, computing time = 22s
# i/Nt=75%, computing time = 22s
# i/Nt=76%, computing time = 22s
# i/Nt=77%, computing time = 23s
# i/Nt=78%, computing time = 23s
# i/Nt=79%, computing time = 23s
# i/Nt=80%, computing time = 23s
# i/Nt=81%, computing time = 24s
# i/Nt=82%, computing time = 24s
# i/Nt=83%, computing time = 24s
# i/Nt=84%, computing time = 25s
# i/Nt=85%, computing time = 25s
# i/Nt=86%, computing time = 25s
# i/Nt=87%, computing time = 26s
# i/Nt=88%, computing time = 26s
# i/Nt=89%, computing time = 26s
# i/Nt=90%, computing time = 26s
# i/Nt=91%, computing time = 27s
# i/Nt=92%, computing time = 27s
# i/Nt=93%, computing time = 27s
# i/Nt=94%, computing time = 28s
# i/Nt=95%, computing time = 28s
# i/Nt=96%, computing time = 28s
# i/Nt=97%, computing time = 28s
# i/Nt=98%, computing time = 29s
# i/Nt=98%, computing time = 29s
# Numerical integration time = 29.29s

# %%
amp_max_nonlin=np.max(np.abs(np.fft.ifft(C)))
## Adimensional amplitude at non-linear focus a*k_p, H/L ##
print('NONLINEAR amplitude at nonlinear focus')
print('ak_p='+str(amp_max_nonlin*np.sqrt(2)))
print('H/L='+str(amp_max_nonlin*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# NONLINEAR amplitude at nonlinear focus
# ak_p=0.3326235232345416
# H/L=0.10587735582283839
# 1/7=0.14285714285714285

# %% [markdown]
# ## Interpolation and cutting
# Interpolating in $x$-space and leaving the useless parts of data.

# %% [markdown]
# *In time* (cutting)

# %%
np.argmax(np.amax(np.abs(np.fft.ifft(C)[4000:,:]),axis=1))
# Out:
# 31

# %%
np.argmax(np.amax(np.abs(np.fft.ifft(C)[4000:,:]),axis=1))
# Out:
# 31

# %%
plt.clf()
plt.plot(np.amax(np.abs(np.fft.ifft(C)[4150:4250,:]),axis=1)/A)
plt.show()

# %%
np.amax(np.abs(np.fft.ifft(C)[4030,:]))/A,np.amax(np.abs(np.fft.ifft(C)[4031,:]))/A,np.amax(np.abs(np.fft.ifft(C)[4032,:]))/A,
# Out:
# (1.5538984112433802, 1.5539003897766783, 1.5538996261911022)

# %%
#nt1=601; nt2=4031;dnt=1
#nt1=601+2200; nt2=4031-1031; dnt=1;nt3=4031  # for evaluation of crest velocities around -13.1Tp
#nt1=601; nt2=4031; dnt=1;nt3=4031 
nt1=601+2838-20; nt2=601+2838+20; dnt=1;nt3=4031 
#(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/(2*np.pi),len(T_axis)
(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/(2*np.pi),len(T_axis)
# Out:
# (array([-7.14      , -7.12833333, -7.11666667, -7.105     , -7.09333333,
#         -7.08166667, -7.07      , -7.05833333, -7.04666667, -7.035     ,
#         -7.02333333, -7.01166667, -7.        , -6.98833333, -6.97666667,
#         -6.965     , -6.95333333, -6.94166667, -6.93      , -6.91833333,
#         -6.90666667, -6.895     , -6.88333333, -6.87166667, -6.86      ,
#         -6.84833333, -6.83666667, -6.825     , -6.81333333, -6.80166667,
#         -6.79      , -6.77833333, -6.76666667, -6.755     , -6.74333333,
#         -6.73166667, -6.72      , -6.70833333, -6.69666667, -6.685     ,
#         -6.67333333]), 5657)

# %%
#t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/w0
t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/w0

# %% [markdown]
# *In space* (interpolating and cutting)

# %%
from scipy import interpolate

# %%
n=nt1;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.xlim(-200,200)
plt.show()

# %%
scale=300
dx_new=dx/scale; dX_new=dX/scale
#X_axis_new=np.arange(-dX*Nx/2,dX*Nx/2,dX_new)
X_axis_new=np.arange(-75,75,dX_new)

# %%
#x_axis=X_axis_new[nx1:nx2+1]/(2*np.sqrt(2)*k0)
x_axis=X_axis_new/(2*np.sqrt(2)*k0)

# %%
#int(Nx*scale),Nx*scale,len(X_axis_new),X_axis_new[0],X_axis_new[-1],X_axis_new[-2],dX*Nx/2,dX*Nx/2+dX_new
Nx,len(X_axis_new),X_axis_new[0],X_axis_new[-1]
# Out:
# (4096, 56930, -75.0, 74.99802167873139)

# %%
temps_depart=time.time()
U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) #interpolated envelope
#option to add a uniform phase-shift
dphi=0.2*np.pi
for n in range(nt1,nt2+1):
    tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
    tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
    U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)
temps_interp=time.time()-temps_depart

# %%
temps_interp/60
# Out:
# 0.0199957807858785

# %%
n=0;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.real(U_new[n,:]),'-r')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.imag(U_new[n,:]),'-r')
plt.xlim(-200,200)
#plt.xlim(-50,50)
#plt.xlim(-5,5)
#plt.xlim(50,60)
plt.show()

# %%
temps_depart=time.time()
# Recalculating the associated sea-surface elevation
eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
             *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )
temps_sse=time.time()-temps_depart

# %%
temps_sse,dt
# Out:
# (0.18656587600708008, 0.14)

# %% [markdown]
# ## Crest velocities

# %%
par2om=-w0/(4*k0**2)
L=sig/(2*np.sqrt(2)*k0)
tau=L**2/par2om
c0=w0/k0
cg0=w0/(2*k0)
ccr_1ord=cg0+0.5*k0*par2om-c0
ccr_grad_1ord=(-c0+cg0)*k0*t_axis/tau
ccr_2ord=c0-cg0-0.5*k0*par2om
ccr_grad_2ord=k0*(1.5*par2om*k0+4*c0-4*cg0)*t_axis/tau
ccr_lapl_2ord=2*((c0-cg0+0.5*k0*par2om)*(t_axis/tau)**2-0.5*k0*par2om)*(k0)**2
Spread_x=np.sqrt(L**2+(L**(-2))*(par2om*t_axis)**2)
c_grad_expect=ccr_grad_1ord[:-2]/((k0*Spread_x[:-2])**2)+0.5*ccr_grad_2ord[:-2]/((k0*Spread_x[:-2])**4)

# %%
from scipy.signal import argrelextrema

# %%
temps_depart=time.time()
extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
extrema=[]
for k in range(len(extrema2[0])):
    extrema.append([extrema2[1][k],extrema2[0][k]])
temps_extr2=time.time()-temps_depart

# %%
temps_extr2/60,len(extrema)
# Out:
# (0.003032573064168294, 697)

# %%
np.max(eta1*k0/(A*np.sqrt(2)))

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=20
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=2400
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=10
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=24
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
temps_depart=time.time()
nmoy=15 # number of time-steps over which the mean velicity is computed
extr_speed1=np.zeros(len(extrema))
for m in range(len(extrema)):
    if (m%int(len(extrema)/100))==0:
        print('computing='+str(int(100*m/len(extrema)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    i=extrema[m][0]; n=extrema[m][1]
    signe=np.sign(eta1[i,n])
    if n<=nmoy:
        i2=False
        for m2 in range(m,len(extrema)):
            if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                    and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                i2=extrema[m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
    else:
        for m2 in range(len(extrema)):
            if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                    and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                i2=extrema[m-m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
temps_speed=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 0s
# computing=1%, computing time = 0s
# computing=2%, computing time = 0s
# computing=3%, computing time = 0s
# computing=4%, computing time = 0s
# computing=5%, computing time = 0s
# computing=6%, computing time = 0s
# computing=6%, computing time = 0s
# computing=7%, computing time = 0s
# computing=8%, computing time = 0s
# computing=9%, computing time = 0s
# computing=10%, computing time = 0s
# computing=11%, computing time = 0s
# computing=12%, computing time = 0s
# computing=12%, computing time = 0s
# computing=13%, computing time = 0s
# computing=14%, computing time = 0s
# computing=15%, computing time = 0s
# computing=16%, computing time = 0s
# computing=17%, computing time = 0s
# computing=18%, computing time = 0s
# computing=18%, computing time = 0s
# computing=19%, computing time = 0s
# computing=20%, computing time = 0s
# computing=21%, computing time = 0s
# computing=22%, computing time = 0s
# computing=23%, computing time = 0s
# computing=24%, computing time = 0s
# computing=24%, computing time = 0s
# computing=25%, computing time = 0s
# computing=26%, computing time = 0s
# computing=27%, computing time = 0s
# computing=28%, computing time = 0s
# computing=29%, computing time = 0s
# computing=30%, computing time = 0s
# computing=30%, computing time = 0s
# computing=31%, computing time = 0s
# computing=32%, computing time = 0s
# computing=33%, computing time = 0s
# computing=34%, computing time = 0s
# computing=35%, computing time = 0s
# computing=36%, computing time = 0s
# computing=37%, computing time = 0s
# computing=37%, computing time = 0s
# computing=38%, computing time = 0s
# computing=39%, computing time = 0s
# computing=40%, computing time = 0s
# computing=41%, computing time = 0s
# computing=42%, computing time = 0s
# computing=43%, computing time = 0s
# computing=43%, computing time = 0s
# computing=44%, computing time = 0s
# computing=45%, computing time = 0s
# computing=46%, computing time = 0s
# computing=47%, computing time = 0s
# computing=48%, computing time = 0s
# computing=49%, computing time = 0s
# computing=49%, computing time = 0s
# computing=50%, computing time = 0s
# computing=51%, computing time = 0s
# computing=52%, computing time = 0s
# computing=53%, computing time = 0s
# computing=54%, computing time = 0s
# computing=55%, computing time = 0s
# computing=55%, computing time = 0s
# computing=56%, computing time = 0s
# computing=57%, computing time = 0s
# computing=58%, computing time = 0s
# computing=59%, computing time = 0s
# computing=60%, computing time = 0s
# computing=61%, computing time = 0s
# computing=61%, computing time = 0s
# computing=62%, computing time = 0s
# computing=63%, computing time = 0s
# computing=64%, computing time = 0s
# computing=65%, computing time = 0s
# computing=66%, computing time = 0s
# computing=67%, computing time = 0s
# computing=68%, computing time = 0s
# computing=68%, computing time = 0s
# computing=69%, computing time = 0s
# computing=70%, computing time = 0s
# computing=71%, computing time = 0s
# computing=72%, computing time = 0s
# computing=73%, computing time = 0s
# computing=74%, computing time = 0s
# computing=74%, computing time = 0s
# computing=75%, computing time = 0s
# computing=76%, computing time = 0s
# computing=77%, computing time = 0s
# computing=78%, computing time = 0s
# computing=79%, computing time = 0s
# computing=80%, computing time = 0s
# computing=80%, computing time = 0s
# computing=81%, computing time = 0s
# computing=82%, computing time = 0s
# computing=83%, computing time = 0s
# computing=84%, computing time = 0s
# computing=85%, computing time = 0s
# computing=86%, computing time = 0s
# computing=86%, computing time = 0s
# computing=87%, computing time = 0s
# computing=88%, computing time = 0s
# computing=89%, computing time = 0s
# computing=90%, computing time = 0s
# computing=91%, computing time = 0s
# computing=92%, computing time = 0s
# computing=92%, computing time = 0s
# computing=93%, computing time = 0s
# computing=94%, computing time = 0s
# computing=95%, computing time = 0s
# computing=96%, computing time = 0s
# computing=97%, computing time = 0s
# computing=98%, computing time = 0s
# computing=98%, computing time = 0s
# computing=99%, computing time = 0s

# %%
temps_speed
# Out:
# 0.28899574279785156

# %%
dt*dnt*nmoy/(2*np.pi/w0),dx_new/(nmoy*dt*dnt),(c0/2)/(L*k0)**2,(dx_new/(nmoy*dt*dnt))/((c0/2)/(L*k0)**2)
# Out:
# (0.17500000000000002,
#  0.015873015873015872,
#  0.37471439801555845,
#  0.042360304159854596)

# %%
n=100
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=100
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
plt.grid()
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
n=2300
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=20
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.8)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %% [markdown]
# #### Iteration for Fig1bis

# %%
nn=20; x_ccr=[]; ccr_adim=[]; t_adim=t_axis[nn]*k0*c0/(2*np.pi)

# %%
temps_depart=time.time()
DPHI=np.linspace(0,2*np.pi,num=100)
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # store the results
    for m in range(len(extrema)):
        if extrema[m][1]==nn:
            x_ccr.append(x_axis[extrema[m][0]]*k0/(2*np.pi))
            ccr_adim.append((extr_speed1[m]-c0/2)/c0)
temps_fig1bis=time.time()-temps_depart
# Out:
# Calculation 2% complete, time=0.0min
# Calculation 3% complete, time=0.0min
# Calculation 4% complete, time=0.0min
# Calculation 5% complete, time=0.1min
# Calculation 6% complete, time=0.1min
# Calculation 7% complete, time=0.1min
# Calculation 8% complete, time=0.1min
# Calculation 9% complete, time=0.2min
# Calculation 10% complete, time=0.2min
# Calculation 11% complete, time=0.2min
# Calculation 12% complete, time=0.3min
# Calculation 13% complete, time=0.3min
# Calculation 14% complete, time=0.3min
# Calculation 15% complete, time=0.3min
# Calculation 16% complete, time=0.4min
# Calculation 17% complete, time=0.4min
# Calculation 18% complete, time=0.4min
# Calculation 19% complete, time=0.5min
# Calculation 20% complete, time=0.5min
# Calculation 21% complete, time=0.5min
# Calculation 22% complete, time=0.6min
# Calculation 23% complete, time=0.6min
# Calculation 24% complete, time=0.6min
# Calculation 25% complete, time=0.7min
# Calculation 26% complete, time=0.7min
# Calculation 27% complete, time=0.7min
# Calculation 28% complete, time=0.7min
# Calculation 29% complete, time=0.8min
# Calculation 30% complete, time=0.8min
# Calculation 31% complete, time=0.8min
# Calculation 32% complete, time=0.9min
# Calculation 33% complete, time=0.9min
# Calculation 34% complete, time=0.9min
# Calculation 35% complete, time=1.0min
# Calculation 36% complete, time=1.0min
# Calculation 37% complete, time=1.0min
# Calculation 38% complete, time=1.0min
# Calculation 39% complete, time=1.1min
# Calculation 40% complete, time=1.1min
# Calculation 41% complete, time=1.1min
# Calculation 42% complete, time=1.2min
# Calculation 43% complete, time=1.2min
# Calculation 44% complete, time=1.2min
# Calculation 45% complete, time=1.3min
# Calculation 46% complete, time=1.3min
# Calculation 47% complete, time=1.3min
# Calculation 48% complete, time=1.3min
# Calculation 49% complete, time=1.4min
# Calculation 50% complete, time=1.4min
# Calculation 51% complete, time=1.4min
# Calculation 52% complete, time=1.5min
# Calculation 53% complete, time=1.5min
# Calculation 54% complete, time=1.5min
# Calculation 55% complete, time=1.5min
# Calculation 56% complete, time=1.6min
# Calculation 57% complete, time=1.6min
# Calculation 58% complete, time=1.6min
# Calculation 59% complete, time=1.7min
# Calculation 60% complete, time=1.7min
# Calculation 61% complete, time=1.7min
# Calculation 62% complete, time=1.7min
# Calculation 63% complete, time=1.8min
# Calculation 64% complete, time=1.8min
# Calculation 65% complete, time=1.8min
# Calculation 66% complete, time=1.9min
# Calculation 67% complete, time=1.9min
# Calculation 68% complete, time=1.9min
# Calculation 69% complete, time=2.0min
# Calculation 70% complete, time=2.0min
# Calculation 71% complete, time=2.0min
# Calculation 72% complete, time=2.0min
# Calculation 73% complete, time=2.1min
# Calculation 74% complete, time=2.1min
# Calculation 75% complete, time=2.1min
# Calculation 76% complete, time=2.2min
# Calculation 77% complete, time=2.2min
# Calculation 78% complete, time=2.2min
# Calculation 79% complete, time=2.3min
# Calculation 80% complete, time=2.3min
# Calculation 81% complete, time=2.3min
# Calculation 82% complete, time=2.3min
# Calculation 83% complete, time=2.4min
# Calculation 84% complete, time=2.4min
# Calculation 85% complete, time=2.4min
# Calculation 86% complete, time=2.5min
# Calculation 87% complete, time=2.5min
# Calculation 88% complete, time=2.5min
# Calculation 89% complete, time=2.5min
# Calculation 90% complete, time=2.6min
# Calculation 91% complete, time=2.6min
# Calculation 92% complete, time=2.6min
# Calculation 93% complete, time=2.7min
# Calculation 94% complete, time=2.7min
# Calculation 95% complete, time=2.7min
# Calculation 96% complete, time=2.7min
# Calculation 97% complete, time=2.8min
# Calculation 98% complete, time=2.8min
# Calculation 99% complete, time=2.8min
# Calculation 101% complete, time=2.9min

# %%
temps_fig1bis/60,len(DPHI)
# Out:
# (2.9421472787857055, 100)

# %%
x_ccr=np.array(x_ccr);ccr_adim=np.array(ccr_adim)

# %%
index=np.argsort(x_ccr)
x_ccr=x_ccr[index];ccr_adim=ccr_adim[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2)
           +(ccr_grad_2ord[nn]*x_axis+0.5*ccr_lapl_2ord[nn]*x_axis**2)/((k0*Spread_x[nn])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2))/c0,'--',color='grey')
ax.plot(x_ccr[17:],ccr_adim[17:],'-k')
ax.set_ylim(-0.5,1)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[nn]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2)
           +(ccr_grad_2ord[nn]*x_axis+0.5*ccr_lapl_2ord[nn]*x_axis**2)/((k0*Spread_x[nn])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2))/c0,'--',color='grey')
ax.plot(x_ccr[6:],ccr_adim[6:],'-.k')
ax.set_ylim(-0.5,1)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[nn]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--',color='grey')
ax.plot(x_ccr[4:],ccr_adim[4:],'-.k')
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
np.savez('c_mes_L5_A0p21_1.npz',x_ccr=np.array(x_ccr),ccr_adim=np.array(ccr_adim),
         t_adim=t_adim,tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
tau*w0/(2*np.pi)
# Out:
# -15.91549430918953

# %% [markdown]
# #### For Fig3 bis

# %%
c_grad_agg=[];t_grad_agg=[]

# %%
temps_depart=time.time()
DPHI=np.linspace(0,2*np.pi,num=4,endpoint=0)
#DPHI=np.array([0.25,0.75,1.63])*np.pi
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # position of the largest crest/trough in space, over time
    eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
    # criterion for having the largest crest/trough close enough to the center of the WP
    thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp) 
    
    # measuring the center gradient
    c_grad_mes=[]
    t_grad_mes=[]
    dist0=np.max(x_axis)*10**2
    LM=linear_model.LinearRegression()

    for n in range(len(t_axis)):
        if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
            and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
            t_grad_mes.append(t_axis[n])
        
            m0=0
            dist=dist0
            for m in range(len(extrema)):
                if (extrema[m][1]==n
                    and np.abs(x_axis[extrema[m][0]])<dist):
                    dist=np.abs(x_axis[extrema[m][0]])
                    m0=m
            
            y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
            X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
            c_grad_mes.append(LM.fit(X,y).coef_[1])
            del X, y

    c_=[c_grad_mes[0]]
    t_=[t_grad_mes[0]]
    for n in range(len(t_grad_mes)-1):
        if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
            c_.append(c_grad_mes[n+1])
            t_.append(t_grad_mes[n+1])
        else:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
            c_=[c_grad_mes[n+1]]
            t_=[t_grad_mes[n+1]]
        if n+1==len(t_grad_mes)-1:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
    
temps_fig3bis=time.time()-temps_depart
# Out:
# Calculation 34% complete, time=3.4min
# Calculation 67% complete, time=6.9min
# Calculation 101% complete, time=10.min

# %%
temps_fig3bis/60,len(DPHI)
# Out:
# (13.959694270292918, 4)

# %%
DPHI/np.pi
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
t_grad_agg=np.array(t_grad_agg); c_grad_agg=np.array(c_grad_agg)

# %%
index=np.argsort(t_grad_agg)
t_grad_agg=t_grad_agg[index];c_grad_agg=c_grad_agg[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
np.savez('c_grad_L5_A0p21_0.npz',t_grad_agg=t_grad_agg,c_grad_agg=c_grad_agg,
         tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_grad_agg/np.abs(tau),
        lowess(c_grad_agg*L*L*k0*k0/(c0*k0), t_grad_agg/np.abs(tau),
               frac=1./8, it=3, return_sorted=False),
        '-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /home/administrateur/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in greater_equal
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)

# %%
n_min=np.argmin(c_grad_agg*L*L*k0*k0/(c0*k0))
t_min_adim=t_grad_agg[n_min]/np.abs(tau)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_grad_agg/np.abs(tau),c_grad_agg*L*L*k0*k0/(c0*k0),'-r')
ax.plot([t_min_adim,t_min_adim],[-2,1],'--k')
#ax.set_xlim([-2,0])
ax.set_ylim([-1.2,0])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
t_axis[2838],t_grad_agg[n_min]
# Out:
# (-82.87999999999995, -82.94999999999995)

# %%
n=2300
spid=0
for m in range(len(extrema)):
    if extrema[m][1]==n:
        diff=(extr_speed1[m]-spid)/(dx_new/(nmoy*dt*dnt))
        spid=extr_speed1[m]
        print('velocity='+str(spid)+', velocity difference / precision ='+str(diff))
# Out:
# velocity=14.047619047591274, velocity difference / precision =884.9999999982504
# velocity=13.269841269815016, velocity difference / precision =-48.999999999904254
# velocity=12.793650793625488, velocity difference / precision =-29.999999999940247
# velocity=12.746031746006537, velocity difference / precision =-2.999999999993946
# velocity=12.253968253944022, velocity difference / precision =-30.999999999938453
# velocity=9.460317460298748, velocity difference / precision =-175.99999999965223
# velocity=8.333333333316848, velocity difference / precision =-70.99999999985975
# velocity=7.7142857142704555, velocity difference / precision =-38.9999999999227
# velocity=7.396825396810765, velocity difference / precision =-19.999999999960483
# velocity=7.269841269826889, velocity difference / precision =-7.999999999984192
# velocity=7.142857142843013, velocity difference / precision =-7.999999999984192
# velocity=7.031746031732111, velocity difference / precision =-6.999999999986826
# velocity=6.904761904748262, velocity difference / precision =-7.9999999999825135
# velocity=6.777777777764305, velocity difference / precision =-7.999999999989284
# velocity=6.60317460316156, velocity difference / precision =-10.999999999972935
# velocity=6.444444444431653, velocity difference / precision =-9.99999999998413
# velocity=6.269841269828908, velocity difference / precision =-10.999999999972935

# %%
# position of the largest crest/trough in space, over time
eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
# criterion for having the largest crest/trough close enough to the center of the WP
thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp)

# %%
temps_depart=time.time()
c_grad_mes=[]
t_grad_mes=[]
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()

for n in range(len(t_axis)):
#    if (n%int((len(t_axis)-2)/100))==0:
#        print('computing='+str(int(100*n/(len(t_axis)-2)))
#    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    
    if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
        and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
        t_grad_mes.append(t_axis[n])
        
        m0=0
        dist=dist0
        for m in range(len(extrema)):
            if (extrema[m][1]==n
                and np.abs(x_axis[extrema[m][0]])<dist):
                dist=np.abs(x_axis[extrema[m][0]])
                m0=m
            
        y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
        X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
        c_grad_mes.append(LM.fit(X,y).coef_[1])
        del X, y
temps_grad=time.time()-temps_depart

# %%
c_grad_agg=[] # "agg" stands for "agglomerate"
t_grad_agg=[]
c_=[c_grad_mes[0]]
t_=[t_grad_mes[0]]
for n in range(len(t_grad_mes)-1):
    if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
        c_.append(c_grad_mes[n+1])
        t_.append(t_grad_mes[n+1])
    else:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))
        c_=[c_grad_mes[n+1]]
        t_=[t_grad_mes[n+1]]
    if n+1==len(t_grad_mes)-1:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
ccr_grad_1ord_=(-c0+cg0)*k0*np.array(t_grad_agg)/tau
Spread_x_=np.sqrt(L**2+(L**(-2))*(par2om*np.array(t_grad_agg))**2)
c_grad_expect_=ccr_grad_1ord_/((k0*Spread_x_)**2)

# %%
A*np.sqrt(2),4*A
# Out:
# (0.21405728070048977, 0.6054454189826743)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
tsurtau=t_axis[:-2]/tau
#ax.plot(tsurtau,c_grad_expect*(1+5*A*np.sqrt(2)*(tsurtau/(1+tsurtau**2))**2 )*L*L*k0*k0/(c0*k0),'--k')
tsurtau_=np.array(t_grad_agg)/tau
ax.plot(-tsurtau_,np.array(c_grad_agg)/c_grad_expect_-1,'k')
#ax.plot(-tsurtau_,(1-tsurtau_*4*A))
#ax.plot(-tsurtau_,2*3*tsurtau_/(1+tsurtau_**2)**3)
ax.plot(-tsurtau_,55*tsurtau_*np.exp(-tsurtau_/0.27),'r')
#ax.plot(-tsurtau_,(tsurtau_/(1+tsurtau_**2))*np.pi*2*np.sqrt(2)*A*np.sqrt(2))
#ax.set_xlim([-2,0])
#ax.set_ylim([0,4.5])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
#ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
#plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
plt.grid()
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
#ax.set_xlim([-2,0])
ax.set_ylim([-3,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes_spl*L*L*k0*k0/(c0*k0),'.r',markersize=1)
#ax.set_xlim([-2,0])
ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes_spl*L*L*k0*k0/(c0*k0),'.r',markersize=1)
ax.plot(t_axis[:-2]/np.abs(tau),
        lowess(c_grad_mes_spl*L*L*k0*k0/(c0*k0), t_axis[:-2]/np.abs(tau), frac=1./10, return_sorted=False),
        '--k',markersize=1)
#ax.set_xlim([-2,0])
ax.set_ylim([-2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
# smoothing taking the median
c_grad_mes_smooth=np.zeros(len(t_axis)-2)
n_smooth=200*2
for n in range(len(t_axis)-2):
    n_low=int(max(0,n-n_smooth/2)); n_high=int(min(len(t_axis)-3,n+n_smooth/2))
    c_grad_mes_smooth[n]=np.median(c_grad_mes_spl[n_low:n_high])

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes_spl*L*L*k0*k0/(c0*k0),'.r',markersize=1)
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes_smooth*L*L*k0*k0/(c0*k0),'--k',markersize=1)
#ax.set_xlim([-2,0])
ax.set_ylim([-2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %% [markdown]
# --------------
# Computing the amplitude over time

# %%
A_adim=np.amax(np.abs(U_new[nt1:nt2+1:dnt,nx1:nx2+1]),axis=1)

# %%
np.argmax(A_adim),len(A_adim)
# Out:
# (3428, 3430)

# %% [markdown]
# Computing the width at focus

# %%
def gauss(x, *p):
    a, mu, sigma = p
    return a*np.exp(-(x-mu)**2/(2*sigma**2))
from scipy.optimize import curve_fit
p0=[1,0,1]

# %%
fit=curve_fit(gauss,x_axis,np.abs(U_new[nt2,nx1:nx2+1]),p0=p0)
L_foc=fit[0][2]

# %%
fit
# Out:
# (array([ 1.64999296e-01, -5.06489150e-05,  9.02553643e+01]),
#  array([[ 2.30753264e-08,  2.11028674e-11, -8.41507690e-06],
#         [ 2.11028674e-11,  9.20108663e-03, -1.71098413e-07],
#         [-8.41507690e-06, -1.71098413e-07,  9.20639464e-03]]))

# %%
k0*L_foc
# Out:
# 2.5223262565886935

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
n=-1; 
ax.plot(x_axis,eta1[:,n])
ax.plot(x_axis,np.abs(U_new[nt2,nx1:nx2+1])*np.sqrt(2)/k0)
ax.plot(x_axis,gauss(x_axis,fit[0][0],fit[0][1],fit[0][2])*np.sqrt(2)/k0,'--')
ax.set_xlim([-700,700])
fig.set_size_inches([7,3])
plt.show()

# %% [markdown]
# --------------
# ### Making the prediction

# %%
def gradient_fit_addNL( time , t0 , Tau , addNL ):
    return 2*addNL*((time-t0)/(Tau**2+(time-t0)**2))

def gradient_fit22( time , t0 , Tau ):
    return 2*((time-t0)/(Tau**2+(time-t0)**2))*( 1-3.25/((k0*c0*Tau/4)*(1+((time-t0)/Tau)**2)) )

# %%
n=1710
len(t_axis),0.5*w0*t_axis[n]/np.pi,2*np.pi/w0,t_axis[n]/60
# Out:
# (3430, -20.055, 12.0, -4.011)

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes-c_grad_expect)

nstart=1715
Nts=len(t_axis)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts-3)
tau_abs=np.zeros(Nts-3)
A_ratio=np.zeros(Nts-3)
addNL_estim=np.zeros(Nts-3)
L_estim=np.zeros(Nts-3)
cov=np.full((Nts-3,3,3),np.inf)

for nend in range(nstart+40,Nts-3):
    n=nend-nstart-40
    if (n%int((Nts-nstart-6)/100))==0:
        print('computing='+str(int(100*n/(Nts-nstart-6)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    popt, pcov = curve_fit(gradient_fit_addNL, t_axis[nstart:nend], c_grad_mes[nstart:nend],
                        p0=[0,10*2*np.pi/(k0*c0),1],sigma=STD_FIT*np.ones(nend-nstart))
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    addNL_estim[nend]=popt[2]
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((t_axis[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# /home/administrateur/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py:779: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# computing=0%, computing time = 0s
# computing=1%, computing time = 1s
# computing=2%, computing time = 1s
# computing=3%, computing time = 1s
# computing=4%, computing time = 1s
# computing=5%, computing time = 1s
# computing=6%, computing time = 1s
# computing=7%, computing time = 1s
# computing=8%, computing time = 1s
# computing=9%, computing time = 1s
# computing=10%, computing time = 1s
# computing=11%, computing time = 1s
# computing=12%, computing time = 2s
# computing=13%, computing time = 2s
# computing=14%, computing time = 2s
# computing=15%, computing time = 2s
# computing=16%, computing time = 2s
# computing=17%, computing time = 2s
# computing=18%, computing time = 2s
# computing=19%, computing time = 2s
# computing=20%, computing time = 2s
# computing=21%, computing time = 2s
# computing=22%, computing time = 2s
# computing=23%, computing time = 2s
# computing=24%, computing time = 3s
# computing=25%, computing time = 3s
# computing=26%, computing time = 3s
# computing=27%, computing time = 3s
# computing=28%, computing time = 3s
# computing=29%, computing time = 3s
# computing=30%, computing time = 3s
# computing=31%, computing time = 3s
# computing=32%, computing time = 3s
# computing=33%, computing time = 3s
# computing=34%, computing time = 3s
# computing=35%, computing time = 3s
# computing=36%, computing time = 3s
# computing=37%, computing time = 4s
# computing=38%, computing time = 4s
# computing=39%, computing time = 4s
# computing=40%, computing time = 4s
# computing=41%, computing time = 4s
# computing=42%, computing time = 4s
# computing=43%, computing time = 4s
# computing=44%, computing time = 4s
# computing=45%, computing time = 4s
# computing=46%, computing time = 4s
# computing=47%, computing time = 4s
# computing=48%, computing time = 4s
# computing=49%, computing time = 4s
# computing=50%, computing time = 4s
# computing=51%, computing time = 4s
# computing=52%, computing time = 4s
# computing=53%, computing time = 5s
# computing=54%, computing time = 5s
# computing=55%, computing time = 5s
# computing=56%, computing time = 5s
# computing=57%, computing time = 5s
# computing=58%, computing time = 5s
# computing=59%, computing time = 5s
# computing=60%, computing time = 5s
# computing=61%, computing time = 5s
# computing=62%, computing time = 5s
# computing=63%, computing time = 6s
# computing=64%, computing time = 6s
# computing=65%, computing time = 6s
# computing=66%, computing time = 6s
# computing=67%, computing time = 6s
# computing=68%, computing time = 6s
# computing=69%, computing time = 6s
# computing=70%, computing time = 6s
# computing=71%, computing time = 6s
# computing=72%, computing time = 7s
# computing=73%, computing time = 7s
# computing=74%, computing time = 7s
# computing=75%, computing time = 7s
# computing=76%, computing time = 7s
# computing=77%, computing time = 7s
# computing=78%, computing time = 7s
# computing=79%, computing time = 7s
# computing=80%, computing time = 7s
# computing=81%, computing time = 8s
# computing=82%, computing time = 8s
# computing=83%, computing time = 8s
# computing=84%, computing time = 8s
# computing=85%, computing time = 8s
# computing=86%, computing time = 8s
# computing=87%, computing time = 8s
# computing=88%, computing time = 8s
# computing=89%, computing time = 8s
# computing=90%, computing time = 8s
# computing=91%, computing time = 8s
# computing=92%, computing time = 9s
# computing=93%, computing time = 9s
# computing=94%, computing time = 9s
# computing=95%, computing time = 9s
# computing=96%, computing time = 9s
# computing=97%, computing time = 9s

# %%
nstart+30,nend
# Out:
# (1745, 1746)

# %%
t_axis[3000]*w0/(2*np.pi)
# Out:
# -5.004999999999999

# %%
#ne=nstart+1600
ne=3000
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),c_grad_mes*L*L*k0*k0/(c0*k0),'.k',markersize=1)
ax.plot(t_axis[nstart:ne]/np.abs(tau),c_grad_mes[nstart:ne]*L*L*k0*k0/(c0*k0),'r',markersize=1)
#ax.plot(t_axis[nstart:ne]/np.abs(tau),gradient_fit22(t_axis[nstart:ne],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':k',markersize=1)
ax.plot(t_axis[nstart:ne]/np.abs(tau),
        gradient_fit_addNL(t_axis[nstart:ne],tfoc[ne],tau_abs[ne],addNL_estim[ne])*L*L*k0*k0/(c0*k0),':k',markersize=1)
#ax.set_xlim([-2,0])
ax.set_ylim([-1.2,0.01])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'-.b',
        label='Estimation')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),t_axis[nstart+2:nend]*w0/(2*np.pi),'--k',
        label='x=y')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-8,2])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
#ax.plot(t_axis[nstart:nend]/np.abs(tau),(1+(t_axis[nstart:nend]/tau)**2)**0.25,'k',
#        label=r'$A_{f}\, /A(t_{end})=\left(1+\left(t_{end}/\tau\right)^2\right)^{1/4}$')
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),(A_adim[nstart:nend]/A_adim[nend])**(-1),'k',
        label='Truth')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'-.b',label='Estimation')
ax.set_ylim([1,3])
#ax.set_xlim([-2.5,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 2.5$')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'-.b',label='Estimation')
ax.set_ylim([2,3])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'-.b',
        label='Estimation')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),t_axis[nstart+2:nend]*w0/(2*np.pi),'--k',
        label='x=y')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-8,2])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
#ax.plot(t_axis[nstart:nend]/np.abs(tau),(1+(t_axis[nstart:nend]/tau)**2)**0.25,'k',
#        label=r'$A_{f}\, /A(t_{end})=\left(1+\left(t_{end}/\tau\right)^2\right)^{1/4}$')
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),(A_adim[nstart:nend]/A_adim[nend])**(-1),'k',
        label='Truth')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'-.b',label='Estimation')
ax.set_ylim([1,3])
#ax.set_xlim([-2.5,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 2.5$')
ax.plot(t_axis[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'-.b',label='Estimation')
ax.set_ylim([2,3])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()
