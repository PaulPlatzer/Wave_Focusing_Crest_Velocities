# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn import linear_model
from scipy.optimize import curve_fit

# %% [markdown]
# # Solving the Non-Linear Schrödinger Equation
#
# In the reference frame moving with the group velocity of waves, the Non-Linear Schrödinger equation for the envelope $u$ of 1D deep-water ocean surgace gravity waves is
# $$i \partial_t u =\frac{\omega_0}{8k_0^2}\partial_{xx} u+\frac{1}{2}\omega_0 k_0^2 |u|^2 u \, , $$
#
# where $\omega_0$ and $k_0$ are the peak pulse and wavenumber of the wave field which is represented as the real part of $u(x,t)\exp i\left(\omega_0 t -k_0 x \right)$, where $x$ is position and $t$ time.
#
# This equation can be non-dimensionalized setting $T=\omega_0 t$, $X=2\sqrt{2}k_0 x$, $U= \frac{k_0}{\sqrt{2}} u$, giving
#
# $$ i\partial_T U = \partial_{XX} U + |U|^2U \, . $$
#
# It will be solved using a pseudo-spectral scheme (see https://en.wikipedia.org/wiki/Pseudo-spectral_method) as is done in Adcock & Taylor (2009, see section 2 for details on the equation and section 3 for details concerning the numerical integration). The shape of the Gaussian wavenumber spectrum is fitted to a JONSWAP spectrum with $\gamma=3.3$ as in Gibbs & Taylor (2005).
#
# ### References
#
#    Adcock, T. A. A., & Taylor, P. H. (2009). Focusing of unidirectional wave groups on deep water: an approximate nonlinear Schrödinger equation-based model. *Proceedings of the Royal Society A: Mathematical, Physical and Engineering Sciences*, 465(2110), 3083-3102.
#
#    Gibbs, R. H., & Taylor, P. H. (2005). Formation of walls of water in ‘fully’nonlinear simulations. Applied Ocean Research, 27(3), 142-157.

# %% [markdown]
# ## RK4

# %%
## 4th-order explicit Runge-Kutta solver for time-independant ODE ##
def RK4(yt,h,f):
    k1=h*f(yt)
    k2=h*f(yt+0.5*k1)
    k3=h*f(yt+0.5*k2)
    k4=h*f(yt+k3)
    dy=(k1+2*k2+2*k3+k4)/6
    return yt+dy
#    return yt+k1

# %% [markdown]
# ## Settings for the equation

# %%
## Physical parameters ##
tp=12 #(s) peak period
grav=9.81 # (m/s^2) gravity acceleration at the earth's surface
w0=2*np.pi/tp # (s^-1) peak pulse
k0=(w0**2)/grav # (m^-1) peak wavenumber
lbda0=2*np.pi/k0 # (m) peak wavelength

# %%
## Domain ##
# Spatial #
dx=10; dX=2*np.sqrt(2)*k0*dx # Spatial discretization
Nx=2**12 # Number of points in space (=number of Fourier modes)
Nlbda=Nx*dx/lbda0 # Number of peak wavelength in the spatial domain
X_axis=np.arange(-dX*Nx/2,dX*Nx/2,dX)
# Temporal #
#Nper=2*1500 # Number of peak period in the temporal domain
Nper=65 # Number of peak period in the temporal domain
dt=0.14; dT=w0*dt # Temporal discretization
Nt=round((Nper+1)*tp/dt)
T_axis=np.arange(0,Nt*dT,dT)

# %%
dx,dt,2*np.max(X_axis)/(2*np.sqrt(2)*k0),w0,k0
# Out:
# (10, 0.14, 40940.000000008804, 0.5235987755982988, 0.027946552274009957)

# %%
## Checking ##
print(len(X_axis),Nx,dX)
print(Nlbda)
print(len(T_axis),Nt,dT)
print(Nper)
# Out:
# 4096 4096 0.7904478649494708
# 182.18319613070267
# 5657 5657 0.07330382858376185
# 65

# %% [markdown]
# ## Initialization

# %%
C=np.zeros((Nt,Nx),np.complex64) # Fourier modes for U

# %% [markdown]
# Start from a linearly back-propagated Gaussian wave packet :

# %%
## Back-propagated Gaussian packet ##
sig=2*np.sqrt(2)*5  # sig = 2sqrt(2)*LfkO where Lf is the spatial width at linear focus
A=0.2*(2**0.25)/sig  # adimensional amplitude
phi0=0#2*np.pi*np.random.rand()  # uniform phase
#U00=A*np.exp(-(X_axis-0.5*Nx*dX)**2/(2*sig**2))
U00=A*np.exp(-X_axis**2/(2*sig**2))*np.exp(1j*phi0)
C00=np.fft.fft(U00)
Delta_T=4*(-0.5*sig**2) # (-0.5*sig**2) corresponds to om0*tau for the article on GWP
                        # and crest velocities

OmNxdX=-(2*np.pi*np.fft.fftfreq(Nx,dX))**2    
                                    # -> This formula for the dispertion relation
                                    # for the envelope is true in the narrow-band limit
                                    # that is used for the NLSE
                                    # and in the reference frame
                                    # moving with the group-velocity
    
C0=C00*np.exp(-1j*OmNxdX*Delta_T)

U0=np.fft.ifft(C0)
C[0,:]=C0

# %%
phi0/np.pi,np.exp(1j*phi0)
# Out:
# (0.0, (1+0j))

# %%
plt.clf()
plt.plot(X_axis,np.abs(U0)/A,'r',label='Initial condition')
plt.plot(X_axis,np.abs(U00)/A,'--k',label='Linear focus corresponding to Initial condition')
plt.legend(bbox_to_anchor=(1, 1)); plt.xlabel("position"); plt.ylabel('amplitude of envelope')
#plt.xlim([-200,200]);
plt.xlim([-1000,1000]);
plt.grid(); plt.show()

# %%
Delta_T,Nt*dT,Delta_T/(2*np.pi),Delta_T/dT
# Out:
# (-400.00000000000006,
#  414.67975829834074,
#  -63.66197723675815,
#  -5456.740906007841)

# %% [markdown]
# Adcock and Taylor (2009) showed that $2^{1/4}$ and $2^{3/4}$ are important thresholds for the ratio (Spectral Amplitude)/(Spectral bandwidth) as far as the behaviour of the wave packet is concerned (actually $2^{1/4}$ is not a real threshold). The next line helps knowing in which region we are.

# %%
## Comparing sig*A, 2^(1/4) and 2^(3/4) ##
sig*A,[2**0.25,2**0.75]
# Out:
# (0.23784142300054423, [1.189207115002721, 1.681792830507429])

# %%
## Adimensional amplitude at linear focus a*k_p, H/L ##
print('ak_p='+str(A*np.sqrt(2)))
print('H/L='+str(A*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# ak_p=0.023784142300054423
# H/L=0.007570727628509405
# 1/7=0.14285714285714285

# %% [markdown]
# ## Defining the equation to be solved
# /!\ WARNING : if $N_x$ or $dX$ is changed, the equation must be redefined before solving.

# %%
## Function for integration of the NLSE in Fourier space ##
def NLS_spec(c_t):
    u_t=np.fft.ifft(c_t)
    c_prime_t=np.fft.fft((np.abs(u_t)**2)*u_t)
    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # original
#    return -1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t - c_prime_t ) # opposite sign, for testing
#    return 1j*( ((2*np.pi*np.fft.fftfreq(Nx,dX))**2)*c_t ) # only propagation, for testing

# %%
Nt,int(Nt/100)
# Out:
# (5657, 56)

# %% [markdown]
# ## Solving

# %%
## Integration of the NLSE ##
temps_depart=time.time()
for i in range(Nt-1):
    C[i+1,:]=RK4(C[i,:],dT,NLS_spec)
    if (i%int(Nt/100))==0:
        print('i/Nt='+str(int(100*i/Nt))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
temps_sim=time.time()-temps_depart
print('Numerical integration time = '+str(round(temps_sim,2))+'s')
# Out:
# i/Nt=0%, computing time = 0s
# i/Nt=0%, computing time = 0s
# i/Nt=1%, computing time = 1s
# i/Nt=2%, computing time = 1s
# i/Nt=3%, computing time = 1s
# i/Nt=4%, computing time = 1s
# i/Nt=5%, computing time = 2s
# i/Nt=6%, computing time = 2s
# i/Nt=7%, computing time = 2s
# i/Nt=8%, computing time = 2s
# i/Nt=9%, computing time = 3s
# i/Nt=10%, computing time = 3s
# i/Nt=11%, computing time = 3s
# i/Nt=12%, computing time = 4s
# i/Nt=13%, computing time = 4s
# i/Nt=14%, computing time = 4s
# i/Nt=15%, computing time = 4s
# i/Nt=16%, computing time = 5s
# i/Nt=17%, computing time = 5s
# i/Nt=18%, computing time = 5s
# i/Nt=19%, computing time = 6s
# i/Nt=20%, computing time = 6s
# i/Nt=21%, computing time = 6s
# i/Nt=22%, computing time = 6s
# i/Nt=23%, computing time = 7s
# i/Nt=24%, computing time = 7s
# i/Nt=25%, computing time = 7s
# i/Nt=26%, computing time = 7s
# i/Nt=27%, computing time = 8s
# i/Nt=28%, computing time = 8s
# i/Nt=29%, computing time = 8s
# i/Nt=30%, computing time = 9s
# i/Nt=31%, computing time = 9s
# i/Nt=32%, computing time = 9s
# i/Nt=33%, computing time = 9s
# i/Nt=34%, computing time = 10s
# i/Nt=35%, computing time = 10s
# i/Nt=36%, computing time = 10s
# i/Nt=37%, computing time = 10s
# i/Nt=38%, computing time = 11s
# i/Nt=39%, computing time = 11s
# i/Nt=40%, computing time = 11s
# i/Nt=41%, computing time = 12s
# i/Nt=42%, computing time = 12s
# i/Nt=43%, computing time = 12s
# i/Nt=44%, computing time = 12s
# i/Nt=45%, computing time = 13s
# i/Nt=46%, computing time = 13s
# i/Nt=47%, computing time = 13s
# i/Nt=48%, computing time = 13s
# i/Nt=49%, computing time = 14s
# i/Nt=50%, computing time = 14s
# i/Nt=51%, computing time = 14s
# i/Nt=52%, computing time = 15s
# i/Nt=53%, computing time = 15s
# i/Nt=54%, computing time = 15s
# i/Nt=55%, computing time = 15s
# i/Nt=56%, computing time = 16s
# i/Nt=57%, computing time = 16s
# i/Nt=58%, computing time = 16s
# i/Nt=59%, computing time = 16s
# i/Nt=60%, computing time = 17s
# i/Nt=61%, computing time = 17s
# i/Nt=62%, computing time = 17s
# i/Nt=63%, computing time = 18s
# i/Nt=64%, computing time = 18s
# i/Nt=65%, computing time = 18s
# i/Nt=66%, computing time = 18s
# i/Nt=67%, computing time = 19s
# i/Nt=68%, computing time = 19s
# i/Nt=69%, computing time = 19s
# i/Nt=70%, computing time = 19s
# i/Nt=71%, computing time = 20s
# i/Nt=72%, computing time = 20s
# i/Nt=73%, computing time = 20s
# i/Nt=74%, computing time = 21s
# i/Nt=75%, computing time = 21s
# i/Nt=76%, computing time = 21s
# i/Nt=77%, computing time = 21s
# i/Nt=78%, computing time = 22s
# i/Nt=79%, computing time = 22s
# i/Nt=80%, computing time = 22s
# i/Nt=81%, computing time = 22s
# i/Nt=82%, computing time = 23s
# i/Nt=83%, computing time = 23s
# i/Nt=84%, computing time = 23s
# i/Nt=85%, computing time = 24s
# i/Nt=86%, computing time = 24s
# i/Nt=87%, computing time = 24s
# i/Nt=88%, computing time = 24s
# i/Nt=89%, computing time = 25s
# i/Nt=90%, computing time = 25s
# i/Nt=91%, computing time = 25s
# i/Nt=92%, computing time = 25s
# i/Nt=93%, computing time = 26s
# i/Nt=94%, computing time = 26s
# i/Nt=95%, computing time = 26s
# i/Nt=96%, computing time = 26s
# i/Nt=97%, computing time = 27s
# i/Nt=98%, computing time = 27s
# i/Nt=98%, computing time = 27s
# Numerical integration time = 27.54s

# %%
amp_max_nonlin=np.max(np.abs(np.fft.ifft(C)))
## Adimensional amplitude at non-linear focus a*k_p, H/L ##
print('NONLINEAR amplitude at nonlinear focus')
print('ak_p='+str(amp_max_nonlin*np.sqrt(2)))
print('H/L='+str(amp_max_nonlin*np.sqrt(2)/np.pi))
print('1/7='+str(1/7))
# Out:
# NONLINEAR amplitude at nonlinear focus
# ak_p=0.02395672243482502
# H/L=0.007625661591565817
# 1/7=0.14285714285714285

# %% [markdown]
# ## Interpolation and cutting
# Interpolating in $x$-space and leaving the useless parts of data.

# %% [markdown]
# *In time* (cutting)

# %%
np.argmax(np.amax(np.abs(np.fft.ifft(C)[5200:,:]),axis=1))
# Out:
# 249

# %%
plt.clf()
plt.plot(np.amax(np.abs(np.fft.ifft(C)[5400:5500,:]),axis=1)/A)
plt.show()

# %%
np.amax(np.abs(np.fft.ifft(C)[5448,:]))/A,np.amax(np.abs(np.fft.ifft(C)[5449,:]))/A,np.amax(np.abs(np.fft.ifft(C)[5450,:]))/A,
# Out:
# (1.007255869634544, 1.0072560765851082, 1.0072560089723617)

# %%
#nt1=2019; nt2=5449;dnt=1
nt1=2019+1950; nt2=2019+2000; nt3=5449;dnt=1
#nt1=2019+2200; nt2=5449-1031; nt3=5449;dnt=1
#(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/(2*np.pi),len(T_axis)
(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/(2*np.pi),len(T_axis)
# Out:
# (array([-17.26666667, -17.255     , -17.24333333, -17.23166667,
#         -17.22      , -17.20833333, -17.19666667, -17.185     ,
#         -17.17333333, -17.16166667, -17.15      , -17.13833333,
#         -17.12666667, -17.115     , -17.10333333, -17.09166667,
#         -17.08      , -17.06833333, -17.05666667, -17.045     ,
#         -17.03333333, -17.02166667, -17.01      , -16.99833333,
#         -16.98666667, -16.975     , -16.96333333, -16.95166667,
#         -16.94      , -16.92833333, -16.91666667, -16.905     ,
#         -16.89333333, -16.88166667, -16.87      , -16.85833333,
#         -16.84666667, -16.835     , -16.82333333, -16.81166667,
#         -16.8       , -16.78833333, -16.77666667, -16.765     ,
#         -16.75333333, -16.74166667, -16.73      , -16.71833333,
#         -16.70666667, -16.695     , -16.68333333]), 5657)

# %%
#t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt2])/w0
t_axis=(T_axis[nt1:nt2+1:dnt]-T_axis[nt3])/w0

# %% [markdown]
# *In space* (interpolating and cutting)

# %%
from scipy import interpolate

# %%
n=nt1;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n,:])),color='cornflowerblue')
plt.xlim(-200,200)
plt.show()

# %%
scale=300
dx_new=dx/scale; dX_new=dX/scale
#X_axis_new=np.arange(-dX*Nx/2,dX*Nx/2,dX_new)
X_axis_new=np.arange(-75,75,dX_new)

# %%
#x_axis=X_axis_new[nx1:nx2+1]/(2*np.sqrt(2)*k0)
x_axis=X_axis_new/(2*np.sqrt(2)*k0)

# %%
#int(Nx*scale),Nx*scale,len(X_axis_new),X_axis_new[0],X_axis_new[-1],X_axis_new[-2],dX*Nx/2,dX*Nx/2+dX_new
Nx,len(X_axis_new),X_axis_new[0],X_axis_new[-1]
# Out:
# (4096, 56930, -75.0, 74.99802167873139)

# %%
temps_depart=time.time()
U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64)
for n in range(nt1,nt2+1):
    tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:])),s=0)
    tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:])),s=0)
    U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)
temps_interp=time.time()-temps_depart

# %%
temps_interp/60,nt2-nt1+1
# Out:
# (0.024309023221333822, 51)

# %%
n=0;plt.clf()
plt.plot(X_axis,np.real(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.real(U_new[n,:]),'-r')
plt.plot(X_axis,np.imag(np.fft.ifft(C[n+nt1,:])),'.',color='cornflowerblue')
plt.plot(X_axis_new,np.imag(U_new[n,:]),'-r')
plt.xlim(-200,200)
#plt.xlim(-50,50)
#plt.xlim(-5,5)
#plt.xlim(50,60)
plt.show()

# %%
temps_depart=time.time()
# Recalculating the associated sea-surface elevation
eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
             *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )
temps_sse=time.time()-temps_depart

# %%
temps_sse,dt,nt2-nt1+1
# Out:
# (0.22633838653564453, 0.14, 51)

# %% [markdown]
# ## Crest velocities

# %%
par2om=-w0/(4*k0**2)
L=sig/(2*np.sqrt(2)*k0)
tau=L**2/par2om
c0=w0/k0
cg0=w0/(2*k0)
ccr_1ord=cg0+0.5*k0*par2om-c0
ccr_grad_1ord=(-c0+cg0)*k0*t_axis/tau
ccr_2ord=c0-cg0-0.5*k0*par2om
ccr_grad_2ord=k0*(1.5*par2om*k0+4*c0-4*cg0)*t_axis/tau
ccr_lapl_2ord=2*((c0-cg0+0.5*k0*par2om)*(t_axis/tau)**2-0.5*k0*par2om)*(k0)**2
Spread_x=np.sqrt(L**2+(L**(-2))*(par2om*t_axis)**2)
c_grad_expect=ccr_grad_1ord[:-2]/((k0*Spread_x[:-2])**2)+0.5*ccr_grad_2ord[:-2]/((k0*Spread_x[:-2])**4)
c_grad_expect1ord=ccr_grad_1ord[:-2]/((k0*Spread_x[:-2])**2)

# %%
from scipy.signal import argrelextrema

# %%
temps_depart=time.time()
extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
extrema=[]
for k in range(len(extrema2[0])):
    extrema.append([extrema2[1][k],extrema2[0][k]])
temps_extr2=time.time()-temps_depart

# %%
temps_extr2/60,len(extrema),nt2-nt1+1
# Out:
# (0.003489963213602702, 887, 51)

# %%
np.max(eta1*k0/(A*np.sqrt(2)))
# Out:
# 1.0053364399047615

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=20
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=2400
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(121)
n=10
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
ax=fig.add_subplot(122)
n=24
ax.plot(x_axis,eta1[:,n])
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]],eta1[extrema[m][0],n],'o')
fig.set_size_inches([10,3])
plt.show()

# %%
temps_depart=time.time()
#nmoy=70 # number of time-steps over which the mean velicity is computed
nmoy=15 # number of time-steps over which the mean velicity is computed
extr_speed1=np.zeros(len(extrema))
for m in range(len(extrema)):
    if (m%int(len(extrema)/100))==0:
        print('computing='+str(int(100*m/len(extrema)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    i=extrema[m][0]; n=extrema[m][1]
    signe=np.sign(eta1[i,n])
    if n<=nmoy:
        i2=False
        for m2 in range(m,len(extrema)):
            if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                    and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
        #        i2=extrema[m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
    else:
        for m2 in range(len(extrema)):
            if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                    and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                i2=extrema[m-m2][0]
                break
        if i2:
            extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
        else:
            extr_speed1[m]=np.nan
temps_speed=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 0s
# computing=1%, computing time = 0s
# computing=2%, computing time = 0s
# computing=3%, computing time = 0s
# computing=4%, computing time = 0s
# computing=5%, computing time = 0s
# computing=6%, computing time = 0s
# computing=7%, computing time = 0s
# computing=8%, computing time = 0s
# computing=9%, computing time = 0s
# computing=9%, computing time = 0s
# computing=10%, computing time = 0s
# computing=11%, computing time = 0s
# computing=12%, computing time = 0s
# computing=13%, computing time = 0s
# computing=14%, computing time = 0s
# computing=15%, computing time = 0s
# computing=16%, computing time = 0s
# computing=17%, computing time = 0s
# computing=18%, computing time = 0s
# computing=18%, computing time = 0s
# computing=19%, computing time = 0s
# computing=20%, computing time = 0s
# computing=21%, computing time = 0s
# computing=22%, computing time = 0s
# computing=23%, computing time = 0s
# computing=24%, computing time = 0s
# computing=25%, computing time = 0s
# computing=26%, computing time = 0s
# computing=27%, computing time = 0s
# computing=27%, computing time = 0s
# computing=28%, computing time = 0s
# computing=29%, computing time = 0s
# computing=30%, computing time = 0s
# computing=31%, computing time = 0s
# computing=32%, computing time = 0s
# computing=33%, computing time = 0s
# computing=34%, computing time = 0s
# computing=35%, computing time = 0s
# computing=36%, computing time = 0s
# computing=36%, computing time = 0s
# computing=37%, computing time = 0s
# computing=38%, computing time = 0s
# computing=39%, computing time = 0s
# computing=40%, computing time = 0s
# computing=41%, computing time = 0s
# computing=42%, computing time = 0s
# computing=43%, computing time = 0s
# computing=44%, computing time = 0s
# computing=45%, computing time = 0s
# computing=45%, computing time = 0s
# computing=46%, computing time = 0s
# computing=47%, computing time = 0s
# computing=48%, computing time = 0s
# computing=49%, computing time = 0s
# computing=50%, computing time = 0s
# computing=51%, computing time = 0s
# computing=52%, computing time = 0s
# computing=53%, computing time = 0s
# computing=54%, computing time = 0s
# computing=55%, computing time = 0s
# computing=55%, computing time = 0s
# computing=56%, computing time = 0s
# computing=57%, computing time = 0s
# computing=58%, computing time = 0s
# computing=59%, computing time = 0s
# computing=60%, computing time = 0s
# computing=61%, computing time = 0s
# computing=62%, computing time = 0s
# computing=63%, computing time = 0s
# computing=64%, computing time = 0s
# computing=64%, computing time = 0s
# computing=65%, computing time = 0s
# computing=66%, computing time = 0s
# computing=67%, computing time = 0s
# computing=68%, computing time = 0s
# computing=69%, computing time = 0s
# computing=70%, computing time = 0s
# computing=71%, computing time = 0s
# computing=72%, computing time = 0s
# computing=73%, computing time = 0s
# computing=73%, computing time = 0s
# computing=74%, computing time = 0s
# computing=75%, computing time = 0s
# computing=76%, computing time = 0s
# computing=77%, computing time = 0s
# computing=78%, computing time = 0s
# computing=79%, computing time = 0s
# computing=80%, computing time = 0s
# computing=81%, computing time = 0s
# computing=82%, computing time = 0s
# computing=82%, computing time = 0s
# computing=83%, computing time = 0s
# computing=84%, computing time = 0s
# computing=85%, computing time = 0s
# computing=86%, computing time = 0s
# computing=87%, computing time = 0s
# computing=88%, computing time = 0s
# computing=89%, computing time = 0s
# computing=90%, computing time = 0s
# computing=91%, computing time = 0s
# computing=91%, computing time = 0s
# computing=92%, computing time = 0s
# computing=93%, computing time = 0s
# computing=94%, computing time = 0s
# computing=95%, computing time = 0s
# computing=96%, computing time = 0s
# computing=97%, computing time = 0s
# computing=98%, computing time = 0s
# computing=99%, computing time = 0s

# %%
dt*dnt*nmoy/(2*np.pi/w0),dx_new/(nmoy*dt*dnt),(c0/2)/(L*k0)**2,(dx_new/(nmoy*dt*dnt))/((c0/2)/(L*k0)**2)
# Out:
# (0.17500000000000002,
#  0.015873015873015872,
#  0.37471439801555845,
#  0.042360304159854596)

# %%
n=100
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=100
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
plt.grid()
fig.set_size_inches(5,4)
plt.show()

# %%
n=2300
plt.clf(); fig=plt.figure(); fig.add_axes()

ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[:,n]/A,'-k',label="Group elevation")
for m in range(len(extrema)):
    if extrema[m][1]==n:
        arrow=ax.arrow(x_axis[extrema[m][0]]*k0/(2*np.pi),2*np.sqrt(2)*k0*eta1[extrema[m][0],n]/A,
                       30*(extr_speed1[m]-c0/2)*k0/(2*np.pi),0,
          head_width=0.1, head_length=15*k0/(2*np.pi), fc='k', ec='k')
ax.plot([0,0],[0,0],'-k',label="$c_{cr}-c_0$ (numerical)")

ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel('$\eta/A$',fontsize=16); #ax.legend(bbox_to_anchor=(1-0.006, 0.01), loc='lower right', borderaxespad=0.,fontsize=12)
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi)); #ax.set_ylim(-1.1,1.1)
fig.set_size_inches(5,4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)

plt.show()

# %%
n=2300
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
n=27
scaling=1
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--k')
for m in range(len(extrema)):
    if extrema[m][1]==n:
        ax.plot(x_axis[extrema[m][0]]*k0/(2*np.pi),scaling*(extr_speed1[m]-c0/2)/c0,'ok',markersize=2.8,label='c1='+str(extr_speed1[m]))
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %% [markdown]
# #### Iteration for Fig1bis

# %%
nn=27; x_ccr=[]; ccr_adim=[]; t_adim=t_axis[nn]*k0*c0/(2*np.pi)

# %%
temps_depart=time.time()
DPHI=np.linspace(0,2*np.pi,num=25)
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # store the results
    for m in range(len(extrema)):
        if extrema[m][1]==nn:
            x_ccr.append(x_axis[extrema[m][0]]*k0/(2*np.pi))
            ccr_adim.append((extr_speed1[m]-c0/2)/c0)
temps_fig1bis=time.time()-temps_depart
# Out:
# Calculation 5% complete, time=0.0min
# Calculation 9% complete, time=0.0min
# Calculation 13% complete, time=0.1min
# Calculation 17% complete, time=0.1min
# Calculation 21% complete, time=0.1min
# Calculation 26% complete, time=0.2min
# Calculation 30% complete, time=0.2min
# Calculation 34% complete, time=0.2min
# Calculation 38% complete, time=0.3min
# Calculation 42% complete, time=0.3min
# Calculation 46% complete, time=0.3min
# Calculation 51% complete, time=0.4min
# Calculation 55% complete, time=0.4min
# Calculation 59% complete, time=0.4min
# Calculation 63% complete, time=0.5min
# Calculation 67% complete, time=0.5min
# Calculation 71% complete, time=0.5min
# Calculation 76% complete, time=0.6min
# Calculation 80% complete, time=0.6min
# Calculation 84% complete, time=0.6min
# Calculation 88% complete, time=0.7min
# Calculation 92% complete, time=0.7min
# Calculation 96% complete, time=0.7min
# Calculation 101% complete, time=0.8min

# %%
temps_fig1bis/60,len(DPHI)
# Out:
# (0.8623411655426025, 25)

# %%
x_ccr=np.array(x_ccr);ccr_adim=np.array(ccr_adim)

# %%
index=np.argsort(x_ccr)
x_ccr=x_ccr[index];ccr_adim=ccr_adim[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2)
           +(ccr_grad_2ord[nn]*x_axis+0.5*ccr_lapl_2ord[nn]*x_axis**2)/((k0*Spread_x[nn])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[nn]*x_axis)/((k0*Spread_x[nn])**2))/c0,'--',color='grey')
ax.plot(x_ccr[5:],ccr_adim[5:],'-.k')
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[nn]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2)
           +(ccr_grad_2ord[n]*x_axis+0.5*ccr_lapl_2ord[n]*x_axis**2)/((k0*Spread_x[n])**4))/c0,'k')
ax.plot(x_axis*k0/(2*np.pi),((ccr_1ord+ccr_grad_1ord[n]*x_axis)/((k0*Spread_x[n])**2))/c0,'--',color='grey')
ax.plot(x_ccr[5:],ccr_adim[5:],'-.k')
ax.set_ylim(-0.5,0.5)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_xlabel('$(x-x_c)/\lambda_0$',fontsize=16);
ax.set_ylabel("$(c_{cr}-c_0)/c_0$",fontsize=16);
plt.title('$t=$'+str(t_axis[n]*k0*c0/(2*np.pi))[0:5]+'$T_p$',fontsize=16)
ax.set_xlim(-1500*k0/(2*np.pi),1500*k0/(2*np.pi));#ax.set_ylim(-0.4,0.4)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches(5,4)
plt.show()

# %%
np.savez('c_mes_L5_A0p024.npz',x_ccr=np.array(x_ccr),ccr_adim=np.array(ccr_adim),
         t_adim=t_adim,tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
tau*w0/(2*np.pi)
# Out:
# -15.91549430918953

# %%
n=2300
spid=0
for m in range(len(extrema)):
    if extrema[m][1]==n:
        diff=(extr_speed1[m]-spid)/(dx_new/(nmoy*dt*dnt))
        spid=extr_speed1[m]
        print('velocity='+str(spid)+', velocity difference / precision ='+str(diff))
# Out:
# velocity=15.857142857111544, velocity difference / precision =998.9999999980273
# velocity=13.61904761902067, velocity difference / precision =-140.9999999997251
# velocity=12.285714285689984, velocity difference / precision =-83.99999999983318
# velocity=11.1587301587081, velocity difference / precision =-70.99999999985874
# velocity=10.253968253947965, velocity difference / precision =-56.99999999988845
# velocity=9.539682539663671, velocity difference / precision =-44.999999999910536
# velocity=8.984126984109214, velocity difference / precision =-34.99999999993083
# velocity=8.523809523792663, velocity difference / precision =-28.999999999942712
# velocity=8.126984126968047, velocity difference / precision =-24.999999999950784
# velocity=7.7777777777623935, velocity difference / precision =-21.999999999956167
# velocity=7.460317460302717, velocity difference / precision =-19.99999999995964
# velocity=7.206349206334937, velocity difference / precision =-15.99999999997012
# velocity=6.999999999986162, velocity difference / precision =-12.999999999972816
# velocity=6.825396825383309, velocity difference / precision =-10.999999999979762
# velocity=6.650793650780618, velocity difference / precision =-10.999999999969521
# velocity=6.4444444444314914, velocity difference / precision =-12.999999999994975
# velocity=6.269841269828962, velocity difference / precision =-10.999999999959337

# %%
temps_depart=time.time()

c_grad_mes=np.zeros(len(t_axis)-2)
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()
for n in range(len(t_axis)-2):
    if (n%int((len(t_axis)-2)/100))==0:
        print('computing='+str(int(100*n/(len(t_axis)-2)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    m0=0
    dist=dist0
    for m in range(len(extrema)):
        if (extrema[m][1]==n
            and np.abs(x_axis[extrema[m][0]])<dist):
            dist=np.abs(x_axis[extrema[m][0]])
            m0=m
            
    y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
               ])
    
    X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
               ])
    
    c_grad_mes[n]=LM.fit(X,y).coef_[1]
    del X, y
temps_grad=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 1s
# computing=1%, computing time = 2s
# computing=2%, computing time = 2s
# computing=3%, computing time = 3s
# computing=4%, computing time = 4s
# computing=5%, computing time = 5s
# computing=6%, computing time = 5s
# computing=7%, computing time = 6s
# computing=8%, computing time = 7s
# computing=9%, computing time = 7s
# computing=10%, computing time = 8s
# computing=11%, computing time = 9s
# computing=12%, computing time = 10s
# computing=13%, computing time = 10s
# computing=14%, computing time = 11s
# computing=15%, computing time = 12s
# computing=16%, computing time = 13s
# computing=17%, computing time = 14s
# computing=18%, computing time = 15s
# computing=19%, computing time = 15s
# computing=20%, computing time = 16s
# computing=21%, computing time = 17s
# computing=22%, computing time = 18s
# computing=23%, computing time = 18s
# computing=24%, computing time = 19s
# computing=25%, computing time = 20s
# computing=26%, computing time = 20s
# computing=27%, computing time = 21s
# computing=28%, computing time = 22s
# computing=29%, computing time = 23s
# computing=30%, computing time = 23s
# computing=31%, computing time = 24s
# computing=32%, computing time = 25s
# computing=33%, computing time = 25s
# computing=34%, computing time = 26s
# computing=35%, computing time = 27s
# computing=36%, computing time = 28s
# computing=37%, computing time = 28s
# computing=38%, computing time = 29s
# computing=39%, computing time = 30s
# computing=40%, computing time = 30s
# computing=41%, computing time = 31s
# computing=42%, computing time = 32s
# computing=43%, computing time = 33s
# computing=44%, computing time = 33s
# computing=45%, computing time = 34s
# computing=46%, computing time = 35s
# computing=47%, computing time = 36s
# computing=48%, computing time = 36s
# computing=49%, computing time = 37s
# computing=50%, computing time = 38s
# computing=51%, computing time = 39s
# computing=52%, computing time = 40s
# computing=53%, computing time = 40s
# computing=54%, computing time = 41s
# computing=55%, computing time = 42s
# computing=56%, computing time = 42s
# computing=57%, computing time = 43s
# computing=58%, computing time = 44s
# computing=59%, computing time = 45s
# computing=60%, computing time = 45s
# computing=61%, computing time = 46s
# computing=62%, computing time = 47s
# computing=63%, computing time = 48s
# computing=64%, computing time = 48s
# computing=65%, computing time = 49s
# computing=66%, computing time = 50s
# computing=67%, computing time = 51s
# computing=68%, computing time = 51s
# computing=69%, computing time = 52s
# computing=70%, computing time = 53s
# computing=71%, computing time = 53s
# computing=72%, computing time = 54s
# computing=73%, computing time = 55s
# computing=74%, computing time = 56s
# computing=75%, computing time = 56s
# computing=76%, computing time = 57s
# computing=77%, computing time = 58s
# computing=78%, computing time = 59s
# computing=79%, computing time = 59s
# computing=80%, computing time = 60s
# computing=81%, computing time = 61s
# computing=82%, computing time = 61s
# computing=83%, computing time = 62s
# computing=84%, computing time = 63s
# computing=85%, computing time = 64s
# computing=86%, computing time = 64s
# computing=87%, computing time = 65s
# computing=88%, computing time = 66s
# computing=89%, computing time = 67s
# computing=90%, computing time = 67s
# computing=91%, computing time = 68s
# computing=92%, computing time = 69s
# computing=93%, computing time = 70s
# computing=94%, computing time = 70s
# computing=95%, computing time = 71s
# computing=96%, computing time = 72s
# computing=97%, computing time = 72s
# computing=98%, computing time = 73s
# computing=99%, computing time = 74s

# %%
# position of the largest crest/trough in space, over time
eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
# criterion for having the largest crest/trough close enough to the center of the WP
thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp)

# %%
temps_depart=time.time()
c_grad_mes=[]
t_grad_mes=[]
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()

for n in range(len(t_axis)):
#    if (n%int((len(t_axis)-2)/100))==0:
#        print('computing='+str(int(100*n/(len(t_axis)-2)))
#    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    
    if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
        and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
        t_grad_mes.append(t_axis[n])
        
        m0=0
        dist=dist0
        for m in range(len(extrema)):
            if (extrema[m][1]==n
                and np.abs(x_axis[extrema[m][0]])<dist):
                dist=np.abs(x_axis[extrema[m][0]])
                m0=m
            
        y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
        X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
        c_grad_mes.append(LM.fit(X,y).coef_[1])
        del X, y
temps_grad=time.time()-temps_depart

# %%
c_grad_agg=[] # "agg" stands for "agglomerate"
t_grad_agg=[]
c_=[c_grad_mes[0]]
t_=[t_grad_mes[0]]
for n in range(len(t_grad_mes)-1):
    if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
        c_.append(c_grad_mes[n+1])
        t_.append(t_grad_mes[n+1])
    else:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))
        c_=[c_grad_mes[n+1]]
        t_=[t_grad_mes[n+1]]
    if n+1==len(t_grad_mes)-1:
        c_grad_agg.append(np.mean(np.array(c_)))
        t_grad_agg.append(np.mean(np.array(t_)))

# %% [markdown]
# #### For Fig3 bis

# %%
c_grad_agg=[];t_grad_agg=[]

# %%
temps_depart=time.time()
#DPHI=np.linspace(0.5*np.pi,2*np.pi,num=3)
DPHI=np.array([0.25,0.75,1.63])*np.pi
avancement=0
for dphi in DPHI:
    if(100*dphi/DPHI[-1])>avancement:
        avancement=int(100*dphi/DPHI[-1])+1
        print('Calculation '+str(avancement)+'% complete, time='
              +str((time.time()-temps_depart)/60)[0:3]+'min')
    #interpolated envelope
    U_new=np.zeros((nt2-nt1+1,len(X_axis_new)),np.complex64) 
    for n in range(nt1,nt2+1):
        tck_re=interpolate.splrep(X_axis,np.real(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        tck_im=interpolate.splrep(X_axis,np.imag(np.fft.ifft(C[n,:]*np.exp(1j*dphi))),s=0)
        U_new[n-nt1,:]=interpolate.splev(X_axis_new,tck_re,der=0)+1j*interpolate.splev(X_axis_new,tck_im,der=0)

    # Recalculating the associated sea-surface elevation
    eta1=np.real( (( (np.sqrt(2)/k0) * U_new * np.exp(1j*k0*x_axis) ).T)
                 *np.exp(1j*(-0.5*T_axis[nt1:nt2+1:dnt])) )

    extrema2=argrelextrema(np.abs(eta1.T), np.greater, axis=1)
    extrema=[]
    for k in range(len(extrema2[0])):
        extrema.append([extrema2[1][k],extrema2[0][k]])

    # compute velocity
    nmoy=15 # number of time-steps over which the mean velicity is computed
    extr_speed1=np.zeros(len(extrema))
    for m in range(len(extrema)):
        i=extrema[m][0]; n=extrema[m][1]
        signe=np.sign(eta1[i,n])
        if n<=nmoy:
            i2=False
            for m2 in range(m,len(extrema)):
                if ( extrema[m2][1]==n+nmoy and extrema[m2][0]-i>0 
                        and np.sign(eta1[extrema[m2][0],extrema[m2][1]])==signe ):
                    i2=extrema[m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i2]-x_axis[i])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan
        else:
            for m2 in range(len(extrema)):
                if ( extrema[m-m2][1]==n-nmoy and extrema[m-m2][0]-i<=0
                        and np.sign(eta1[extrema[m-m2][0],extrema[m-m2][1]])==signe ):
                    i2=extrema[m-m2][0]
                    break
            if i2:
                extr_speed1[m]=(x_axis[i]-x_axis[i2])/(nmoy*dt*dnt)
            else:
                extr_speed1[m]=np.nan

    # position of the largest crest/trough in space, over time
    eta_abs_argmax=np.argmax(np.abs(eta1),axis=0)
    # criterion for having the largest crest/trough close enough to the center of the WP
    thresh_center= 4 * ((2*np.pi)/k0) * dt/(2*tp) 
    
    # measuring the center gradient
    c_grad_mes=[]
    t_grad_mes=[]
    dist0=np.max(x_axis)*10**2
    LM=linear_model.LinearRegression()

    for n in range(len(t_axis)):
        if (-thresh_center/2<x_axis[eta_abs_argmax[n]]
            and x_axis[eta_abs_argmax[n]]<thresh_center/2):
        
            t_grad_mes.append(t_axis[n])
        
            m0=0
            dist=dist0
            for m in range(len(extrema)):
                if (extrema[m][1]==n
                    and np.abs(x_axis[extrema[m][0]])<dist):
                    dist=np.abs(x_axis[extrema[m][0]])
                    m0=m
            
            y=np.array([  
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1]  
                   ])
    
            X=np.array([ 
                [1,x_axis[extrema[m0-1][0]],x_axis[extrema[m0-1][0]]**2] , 
                [1,x_axis[extrema[m0][0]],x_axis[extrema[m0][0]]**2] ,
                [1,x_axis[extrema[m0+1][0]],x_axis[extrema[m0+1][0]]**2] 
                   ])
    
            c_grad_mes.append(LM.fit(X,y).coef_[1])
            del X, y

    c_=[c_grad_mes[0]]
    t_=[t_grad_mes[0]]
    for n in range(len(t_grad_mes)-1):
        if t_grad_mes[n+1]-t_grad_mes[n]<2*dt:
            c_.append(c_grad_mes[n+1])
            t_.append(t_grad_mes[n+1])
        else:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
            c_=[c_grad_mes[n+1]]
            t_=[t_grad_mes[n+1]]
        if n+1==len(t_grad_mes)-1:
            c_grad_agg.append(np.mean(np.array(c_)))
            t_grad_agg.append(np.mean(np.array(t_)))
    
temps_fig3bis=time.time()-temps_depart
# Out:
# Calculation 16% complete, time=5.7min
# Calculation 47% complete, time=3.3min
# Calculation 101% complete, time=6.7min

# %%
temps_fig3bis/60,len(DPHI)
# Out:
# (10.236918660004934, 3)

# %%
DPHI/np.pi
# Out:
# array([0.5 , 1.25, 2.  ])

# %%
t_grad_agg=np.array(t_grad_agg); c_grad_agg=np.array(c_grad_agg)

# %%
index=np.argsort(t_grad_agg)
t_grad_agg=t_grad_agg[index];c_grad_agg=c_grad_agg[index]

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect1ord*L*L*k0*k0/(c0*k0),'--k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'.r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
np.savez('c_grad_L5_A0p024_0.npz',t_grad_agg=t_grad_agg,c_grad_agg=c_grad_agg,
         tau=tau,L=L,alkp=A*np.sqrt(2))

# %%
npzfile1=np.load('c_grad_L5_A0p024_0.npz')

# %%
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
#ax.plot(t_axis[:-2]/np.abs(tau),
#        c_grad_expect1ord*L*L*k0*k0/(c0*k0),'--k')
ax.plot(npzfile1['t_grad_agg']/np.abs(tau),
        lowess(npzfile1['c_grad_agg']*L*L*k0*k0/(c0*k0), npzfile1['t_grad_agg']/np.abs(tau),
               frac=1./5, it=3, return_sorted=False),
        '-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
n_min=np.argmin(lowess(npzfile1['c_grad_agg']*L*L*k0*k0/(c0*k0), npzfile1['t_grad_agg']/np.abs(tau),
               frac=1./5, it=3, return_sorted=False))
t_min_adim=npzfile1['t_grad_agg'][n_min]/np.abs(tau)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(npzfile1['t_grad_agg']/np.abs(tau),npzfile1['c_grad_agg']*L*L*k0*k0/(c0*k0),'-r')
ax.plot([t_min_adim,t_min_adim],[-1,1],'--k')
#ax.set_xlim([-2,0])
ax.set_ylim([-.25,0])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
t_axis[1977],npzfile1['t_grad_agg'][n_min]
# Out:
# (-203.4200000000001, -203.49000000000007)

# %%
len(t_axis)
# Out:
# 3431

# %% [markdown]
# ----------

# %%
temps_depart=time.time()

c_grad_mes_spl=np.zeros(len(t_axis)-2)
c_spl=[]
dist0=np.max(x_axis)*10**2
LM=linear_model.LinearRegression()
xnew=np.arange(-np.pi/k0,np.pi/k0,(2*np.pi/k0)/50)
for n in range(len(t_axis)-2):
    if (n%int((len(t_axis)-2)/100))==0:
        print('computing='+str(int(100*n/(len(t_axis)-2)))
    +'%, computing time = '+str(int(round(time.time()-temps_depart,0)))+'s')
    m0=0
    dist=dist0
    for m in range(len(extrema)):
        if (extrema[m][1]==n
            and np.abs(x_axis[extrema[m][0]])<dist):
            dist=np.abs(x_axis[extrema[m][0]])
            m0=m
            
    y=np.array([  
                extr_speed1[m0-2] , 
                extr_speed1[m0-1] , 
                extr_speed1[m0] ,
                extr_speed1[m0+1],
                extr_speed1[m0+2]  
               ])
    
    x=np.array([ 
                [x_axis[extrema[m0-2][0]]],
                [x_axis[extrema[m0-1][0]]],
                [x_axis[extrema[m0][0]]],
                [x_axis[extrema[m0+1][0]]],
                [x_axis[extrema[m0+2][0]]]
               ])
    
    interpol=interpolate.splrep(x,y)
    ynew=interpolate.splev(xnew,interpol,der=0)
    
    c_grad_mes_spl[n]=LM.fit(np.array([xnew]).T,ynew).coef_[0]
    c_spl.append(ynew)
    del x, y, ynew
temps_grad=time.time()-temps_depart
# Out:
# computing=0%, computing time = 0s
# computing=0%, computing time = 2s
# computing=1%, computing time = 4s
# computing=2%, computing time = 6s
# computing=3%, computing time = 7s
# computing=4%, computing time = 10s
# computing=5%, computing time = 12s
# computing=6%, computing time = 13s
# computing=7%, computing time = 15s
# computing=8%, computing time = 17s
# computing=9%, computing time = 19s
# computing=10%, computing time = 21s
# computing=11%, computing time = 23s
# computing=12%, computing time = 24s
# computing=13%, computing time = 26s
# computing=14%, computing time = 28s
# computing=15%, computing time = 30s
# computing=16%, computing time = 32s
# computing=17%, computing time = 33s
# computing=18%, computing time = 35s
# computing=19%, computing time = 37s
# computing=20%, computing time = 39s
# computing=21%, computing time = 40s
# computing=22%, computing time = 42s
# computing=23%, computing time = 44s
# computing=24%, computing time = 46s
# computing=25%, computing time = 48s
# computing=26%, computing time = 49s
# computing=27%, computing time = 51s
# computing=28%, computing time = 53s
# computing=29%, computing time = 55s
# computing=30%, computing time = 56s
# computing=31%, computing time = 58s
# computing=32%, computing time = 60s
# computing=33%, computing time = 62s
# computing=34%, computing time = 63s
# computing=35%, computing time = 65s
# computing=36%, computing time = 67s
# computing=37%, computing time = 69s
# computing=38%, computing time = 70s
# computing=39%, computing time = 72s
# computing=40%, computing time = 74s
# computing=41%, computing time = 76s
# computing=42%, computing time = 78s
# computing=43%, computing time = 79s
# computing=44%, computing time = 81s
# computing=45%, computing time = 83s
# computing=46%, computing time = 85s
# computing=47%, computing time = 87s
# computing=48%, computing time = 88s
# computing=49%, computing time = 90s
# computing=50%, computing time = 92s
# computing=51%, computing time = 94s
# computing=52%, computing time = 95s
# computing=53%, computing time = 97s
# computing=54%, computing time = 99s
# computing=55%, computing time = 101s
# computing=56%, computing time = 103s
# computing=57%, computing time = 105s
# computing=58%, computing time = 106s
# computing=59%, computing time = 108s
# computing=60%, computing time = 110s
# computing=61%, computing time = 112s
# computing=62%, computing time = 114s
# computing=63%, computing time = 115s
# computing=64%, computing time = 117s
# computing=65%, computing time = 119s
# computing=66%, computing time = 121s
# computing=67%, computing time = 123s
# computing=68%, computing time = 124s
# computing=69%, computing time = 126s
# computing=70%, computing time = 128s
# computing=71%, computing time = 130s
# computing=72%, computing time = 132s
# computing=73%, computing time = 134s
# computing=74%, computing time = 136s
# computing=75%, computing time = 139s
# computing=76%, computing time = 141s
# computing=77%, computing time = 143s
# computing=78%, computing time = 145s
# computing=79%, computing time = 147s
# computing=80%, computing time = 149s
# computing=81%, computing time = 151s
# computing=82%, computing time = 153s
# computing=83%, computing time = 155s
# computing=84%, computing time = 157s
# computing=85%, computing time = 160s
# computing=86%, computing time = 162s
# computing=87%, computing time = 164s
# computing=88%, computing time = 166s
# computing=89%, computing time = 168s
# computing=90%, computing time = 170s
# computing=91%, computing time = 172s
# computing=92%, computing time = 174s
# computing=93%, computing time = 176s
# computing=94%, computing time = 178s
# computing=95%, computing time = 180s
# computing=96%, computing time = 182s
# computing=97%, computing time = 184s
# computing=98%, computing time = 186s
# computing=99%, computing time = 188s

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect1ord*L*L*k0*k0/(c0*k0),'--k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_mes)/np.abs(tau),np.array(c_grad_mes)*L*L*k0*k0/(c0*k0),'.b',markersize=1)
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'-r')
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
ccr_grad_1ord_=(-c0+cg0)*k0*np.array(t_grad_agg)/tau
Spread_x_=np.sqrt(L**2+(L**(-2))*(par2om*np.array(t_grad_agg))**2)
c_grad_expect_=ccr_grad_1ord_/((k0*Spread_x_)**2)

# %%
A*np.sqrt(2),4*A
# Out:
# (0.023784142300054423, 0.06727171322029717)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
tsurtau=t_axis[:-2]/tau
#ax.plot(tsurtau,c_grad_expect*(1+5*A*np.sqrt(2)*(tsurtau/(1+tsurtau**2))**2 )*L*L*k0*k0/(c0*k0),'--k')
tsurtau_=np.array(t_grad_agg)/tau
ax.plot(-tsurtau_,np.array(c_grad_agg)/c_grad_expect_-1)
#ax.plot(-tsurtau_,(1-tsurtau_*4*A))
#ax.plot(-tsurtau_,(tsurtau_/(1+tsurtau_**2))*np.pi*2*np.sqrt(2)*A*np.sqrt(2))
#ax.set_xlim([-2,0])
#ax.set_ylim([-1.2,0.1])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
#ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
#plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %% [markdown]
# --------------
# Computing the amplitude over time

# %%
A_adim=np.amax(np.abs(U_new),axis=1)

# %% [markdown]
# Computing the width at focus

# %%
def gauss(x, *p):
    a, mu, sigma = p
    return a*np.exp(-(x-mu)**2/(2*sigma**2))
from scipy.optimize import curve_fit
p0=[1,0,1]

# %%
fit=curve_fit(gauss,x_axis,np.abs(U_new[-1,:]),p0=p0)
L_foc=fit[0][2]
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py:779: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
k0*L_foc
# Out:
# 4.924645111340675

# %% [markdown]
# --------------
# ### Making the prediction

# %%
def gradient_fit( time , t0 , Tau ):
    return 2*((time-t0)/(Tau**2+(time-t0)**2))

def gradient_fit_addNL( time , t0 , Tau , addNL ):
    return 2*addNL*((time-t0)/(Tau**2+(time-t0)**2))

def gradient_fit22( time , t0 , Tau ):
    return 2*((time-t0)/(Tau**2+(time-t0)**2))*( 1-3.25/((k0*c0*Tau/4)*(1+((time-t0)/Tau)**2)) )

# %%
len(t_grad_agg)
# Out:
# 40

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)

nstart=0
Nts=len(t_grad_agg)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts)
tau_abs=np.zeros(Nts)
A_ratio=np.zeros(Nts)
L_estim=np.zeros(Nts)
cov=np.full((Nts,2,2),np.inf)

for nend in range(nstart+3,Nts):
    n=nend-nstart-3
    popt, pcov = curve_fit(gradient_fit22, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
                       ,sigma=STD_FIT*np.ones(nend-nstart))#,bounds=([-np.inf,0],np.inf)
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'.b',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([1,2])
#ax.set_xlim([-2.5,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([4.5,5.5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)

nstart=0
Nts=len(t_grad_agg)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts)
tau_abs=np.zeros(Nts)
A_ratio=np.zeros(Nts)
L_estim=np.zeros(Nts)
cov=np.full((Nts,2,2),np.inf)

for nend in range(nstart+3,Nts):
    n=nend-nstart-3
    popt, pcov = curve_fit(gradient_fit, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],p0=[0,10*2*np.pi/(k0*c0)]
                       ,sigma=STD_FIT*np.ones(nend-nstart))#,bounds=([-np.inf,0],np.inf)
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'.b',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([1,2])
#ax.set_xlim([-2.5,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([4.5,5.5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
#ne=nstart+1600
ne=35
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis[:-2]/np.abs(tau),
        c_grad_expect*L*L*k0*k0/(c0*k0),'-k')
ax.plot(np.array(t_grad_agg)/np.abs(tau),np.array(c_grad_agg)*L*L*k0*k0/(c0*k0),'.k',markersize=1)
ax.plot(np.array(t_grad_agg)[:ne]/np.abs(tau),np.array(c_grad_agg)[:ne]*L*L*k0*k0/(c0*k0),'r',markersize=1)
#ax.plot(t_axis[nstart:ne]/np.abs(tau),gradient_fit22(t_axis[nstart:ne],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':k',markersize=1)
ax.plot(np.array(t_grad_agg)[:]/np.abs(tau),
        gradient_fit(np.array(t_grad_agg)[:],tfoc[ne],tau_abs[ne])*L*L*k0*k0/(c0*k0),':g',linewidth=2)
#ax.set_xlim([-2,0])
ax.set_ylim([-1,0.01])
ftsz=22
ax.set_xlabel(r'$t/ |\tau|$',fontsize=ftsz);
ax.set_ylabel(r"$\dfrac{(L_f\, k_0)^2}{ \omega_0} \; \partial_x c_{cr}|_{x=x_c}$",fontsize=ftsz)
plt.title(r'Gradient estimation, $L_f\, k_0=5$',fontsize=ftsz)
ax.tick_params(length=7,labelsize=ftsz,direction='out',pad=10)
fig.set_size_inches([6,6])
plt.show()

# %%
temps_depart=time.time()

STD_FIT=np.std(c_grad_mes_spl-c_grad_expect)

nstart=0
Nts=len(t_grad_agg)
# tfoc, A_ratio and L are predicted values based on the best fit
tfoc=np.zeros(Nts)
tau_abs=np.zeros(Nts)
A_ratio=np.zeros(Nts)
L_estim=np.zeros(Nts)
cov=np.full((Nts,3,3),np.inf)

for nend in range(nstart+3,Nts):
    n=nend-nstart-3
    popt, pcov = curve_fit(gradient_fit_addNL, np.array(t_grad_agg)[nstart:nend], np.array(c_grad_agg)[nstart:nend],
                        p0=[0,10*2*np.pi/(k0*c0),2],sigma=STD_FIT*np.ones(nend-nstart))#,bounds=([-np.inf,0],np.inf)
    tfoc[nend]=popt[0]
    tau_abs[nend]=np.abs(popt[1])
    L_estim[nend]=(c0*np.abs(popt[1])/(4*k0))**0.5
    A_ratio[nend]=(1+((np.array(t_grad_agg)[nend]+popt[0])/popt[1])**2)**0.25
    cov[nend,:,:]=pcov

temps_fit=time.time()-temps_depart
# Out:
# /home/administrateur/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py:779: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),np.zeros(len(t_axis[nstart:nend])),'k',label=r'$t_{foc}/T_p=0$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),tfoc[nstart+2:nend]*c0*k0/(2*np.pi),'.b',
        label='Estimation')
ax.set_title('Focusing time estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel('$t_{foc}/T_p$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
ax.set_ylim([-5,5])
#ax.set_xlim([-2.5,0])
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(t_axis*w0/(2*np.pi),(A_adim/A_adim[-1])**(-1),'k',
        label='Truth')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),A_ratio[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([1,4])
#ax.set_xlim([-2.5,0])
ax.set_title('Amplitude ratio estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$A_{f}\, /A(t_{end})$',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
plt.clf(); fig=plt.figure(); fig.add_axes(); ax=fig.add_subplot(111)
ax.plot(np.array(t_grad_agg)[nstart:nend]*w0/(2*np.pi),k0*L_foc*np.ones(len(t_axis[nstart:nend])),'k',label=r'$L_{f}k_0\approx 3.9$')
ax.plot(np.array(t_grad_agg)[nstart+2:nend]*w0/(2*np.pi),k0*L_estim[nstart+2:nend],'.b',label='Estimation')
ax.set_ylim([3.8,4.1])
ax.set_ylim([0,5])
#ax.set_xlim([-2,0])
ax.set_title('Group size estimation',fontsize=16)
ax.set_xlabel(r'$t_{end}/T_p$',fontsize=16)
ax.set_ylabel(r'$L_{f}k_0 $',fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=16)
ax.tick_params(length=7,labelsize=16,direction='out',pad=10)
fig.set_size_inches([7,5])
plt.show()

# %%
n=1715
len(t_axis),0.5*w0*t_axis[n]/np.pi,2*np.pi/w0,t_axis[n]/60
# Out:
# (3431, -20.008333333333333, 12.0, -4.001666666666667)
